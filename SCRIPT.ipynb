# %%
import pandas as pd
import numpy as np

# %%
pd.options.display.max_columns = None

# %%
df = pd.read_excel('EDERJAKIN_LA_Datos_2021.xlsm', sheet_name=None)

# %%
for sheet_name in list(df.keys()):
   df[sheet_name].to_csv(sheet_name + 'Sheet.csv')

# %%
Usuarios = pd.read_csv('UsuariosSheet.csv')
Tutores_perfil = pd.read_csv('Tutores_perfilSheet.csv')
Conocimientos = pd.read_csv('ConocimientosSheet.csv')
Cursos = pd.read_csv('CursosSheet.csv')
Programas = pd.read_csv('ProgramasSheet.csv')
Cursos_en_Programas = pd.read_csv('Cursos_en_ProgramasSheet.csv')
Itinearios = pd.read_csv('ItineariosSheet.csv')
Notas_Cursos = pd.read_csv('Notas_CursosSheet.csv')
Roles = pd.read_csv('RolesSheet.csv')
Plantas = pd.read_csv('PlantasSheet.csv')
Accesos = pd.read_csv('AccesosSheet.csv')
Acceso_1ero_ultimo = pd.read_csv('Acceso_1ero_ultimoSheet.csv')
Actividades = pd.read_csv('ActividadesSheet.csv')

# %%
Actividades.info()
Actividades.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3464 entries, 0 to 3463
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      3464 non-null   int64
#  1   mdl_user_id     3464 non-null   int64
#  2   course_name     3464 non-null   object
#  3   course_id       3464 non-null   int64
#  4   category        3464 non-null   object
#  5   actividad_name  3460 non-null   object
#  6   grade           2114 non-null   float64
#  7   time            2129 non-null   object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 216.6+ KB
# (3464, 8)

# %%
Conocimientos.drop(['Unnamed: 0'], axis=1)

Cursos_en_Programas.drop(['Unnamed: 0'], axis=1)

Usuarios.drop(['Unnamed: 0'], axis=1)

Tutores_perfil.drop(['Unnamed: 0'], axis=1)

Cursos.drop(['Unnamed: 0'], axis=1)

Programas.drop(['Unnamed: 0'], axis=1)

Itinearios.drop(['Unnamed: 0'], axis=1)

Notas_Cursos.drop(['Unnamed: 0'], axis=1)

Roles.drop(['Unnamed: 0'], axis=1)

Plantas.drop(['Unnamed: 0'], axis=1)

Accesos.drop(['Unnamed: 0'], axis=1)

Acceso_1ero_ultimo.drop(['Unnamed: 0'], axis=1)

Actividades.drop(['Unnamed: 0'], axis=1)
# Out:
#       mdl_user_id                           course_name  course_id  \
# 0             190  A - FORMACIÓN ESPECÍFICA CALIDAD ABP        224
# 1             190  A - FORMACIÓN ESPECÍFICA CALIDAD ABP        224
# 2             296  A - FORMACIÓN ESPECÍFICA CALIDAD ABP        224
# 3             296  A - FORMACIÓN ESPECÍFICA CALIDAD ABP        224
# 4             299  A - FORMACIÓN ESPECÍFICA CALIDAD ABP        224
# ...           ...                                   ...        ...
# 3459           21                Trazabilidad LPPFe MEC        278
# 3460           21                Trazabilidad LPPFe MEC        278
# 3461           21                Trazabilidad LPPFe MEC        278
# 3462          339                Trazabilidad LPPFe MEC        278
# 3463          339                Trazabilidad LPPFe MEC        278
#
#                          category  \
# 0       TÉCNICOS/TECNOLÓGICOS ABP
# 1       TÉCNICOS/TECNOLÓGICOS ABP
# 2       TÉCNICOS/TECNOLÓGICOS ABP
# 3       TÉCNICOS/TECNOLÓGICOS ABP
# 4       TÉCNICOS/TECNOLÓGICOS ABP
# ...                           ...
# 3459  Técnico / Tecnológico LPPFE
# 3460  Técnico / Tecnológico LPPFE
# 3461  Técnico / Tecnológico LPPFE
# 3462  Técnico / Tecnológico LPPFE
# 3463  Técnico / Tecnológico LPPFE
#
#                                          actividad_name  grade  \
# 0                                            TEST FINAL    NaN
# 1          A - FORMACIÓN ESPECÍFICA CALIDAD ABP - Total    NaN
# 2          A - FORMACIÓN ESPECÍFICA CALIDAD ABP - Total   9.32
# 3                                            TEST FINAL   9.32
# 4                                            TEST FINAL   9.66
# ...                                                 ...    ...
# 3459  TEST - Enbalajearen etiketa / Etiquetado de em...   9.29
# 3460                     Trazabilidad LPPFe MEC - Total   9.29
# 3461                     Trazabilidad LPPFe MEC - Total   9.29
# 3462                     Trazabilidad LPPFe MEC - Total  10.00
# 3463  TEST - Enbalajearen etiketa / Etiquetado de em...  10.00
#
#                      time
# 0                     NaN
# 1                     NaN
# 2     2020-12-18 15:25:05
# 3     2020-12-18 15:25:05
# 4     2020-12-18 16:45:34
# ...                   ...
# 3459  2021-06-14 16:36:31
# 3460  2021-06-14 16:36:32
# 3461  2021-06-14 16:36:32
# 3462  2021-06-14 10:13:15
# 3463  2021-06-14 10:13:15
#
# [3464 rows x 7 columns]

# %% [markdown]
# UNIONES

# %%
INFORMACION_TUTORES=pd.merge(Usuarios,Tutores_perfil,on="user_id")

# %%
INFORMACION_TUTORES.shape
# Out:
# (180, 16)

# %%
INFORMACION_TUTORES
# Out:
#      Unnamed: 0_x  user_id useranonimo_name  active_flag language  \
# 0               0        3      username_03            1       es
# 1               1        4      username_04            1       es
# 2               7       10      username_10            1       es
# 3               7       10      username_10            1       es
# 4               7       10      username_10            1       es
# ..            ...      ...              ...          ...      ...
# 175           353      369     username_369            1       es
# 176           363      379     username_379            1       es
# 177           398      415     username_415            1       es
# 178           406      423     username_423            1       es
# 179           419      436     username_436            1       es
#
#      last_access  mdl_user_id  role_admin  role_manager  role_student  \
# 0            NaN         13.0           0             0             1
# 1            NaN         14.0           0             0             1
# 2            NaN         21.0           0             0             1
# 3            NaN         21.0           0             0             1
# 4            NaN         21.0           0             0             1
# ..           ...          ...         ...           ...           ...
# 175          NaN        393.0           0             0             1
# 176          NaN        444.0           0             0             1
# 177          NaN        446.0           0             0             1
# 178          NaN        448.0           0             0             1
# 179          NaN        461.0           0             1             1
#
#      role_tutor      planta_name  Unnamed: 11  Unnamed: 0_y  perfil_id  \
# 0             0      ABP Bergara          NaN           118          0
# 1             0     Fagorederlan          NaN           119          0
# 2             1   LPP Eskoriatza          NaN             0          3
# 3             1   LPP Eskoriatza          NaN            22          6
# 4             1   LPP Eskoriatza          NaN           120          0
# ..          ...              ...          ...           ...        ...
# 175           0  MT Aretxabaleta          NaN           184          0
# 176           0  MT Aretxabaleta          NaN           185          0
# 177           0  MT Aretxabaleta          NaN           186          0
# 178           0  MT Aretxabaleta          NaN           187          0
# 179           1      ABP Bergara          NaN            88          6
#
#            perfil_name
# 0                  NaN
# 1                  NaN
# 2    Gestor de empresa
# 3        Tutor empresa
# 4                  NaN
# ..                 ...
# 175                NaN
# 176                NaN
# 177                NaN
# 178                NaN
# 179      Tutor empresa
#
# [180 rows x 16 columns]

# %%
JOIN1_1=pd.merge(Usuarios,Actividades,on="mdl_user_id")

# %%
JOIN1_2=pd.merge(JOIN1_1,Accesos,on="user_id") #ASI YA TENEMOS CON USER ID Y HACEMOS LO QUE QUEREMOS

# %%
JOIN1_3=pd.merge(JOIN1_2,Itinearios,on="user_id")

# %%
JOIN1_3
# Out:
#          Unnamed: 0_x  user_id useranonimo_name  active_flag_x language  \
# 0                   0        3      username_03              1       es
# 1                   0        3      username_03              1       es
# 2                   0        3      username_03              1       es
# 3                   0        3      username_03              1       es
# 4                   0        3      username_03              1       es
# ...               ...      ...              ...            ...      ...
# 1320449           405      422     username_422              1       es
# 1320450           405      422     username_422              1       es
# 1320451           405      422     username_422              1       es
# 1320452           405      422     username_422              1       es
# 1320453           405      422     username_422              1       es
#
#          last_access  mdl_user_id_x  role_admin  role_manager  role_student  \
# 0                NaN           13.0           0             0             1
# 1                NaN           13.0           0             0             1
# 2                NaN           13.0           0             0             1
# 3                NaN           13.0           0             0             1
# 4                NaN           13.0           0             0             1
# ...              ...            ...         ...           ...           ...
# 1320449          NaN          443.0           0             0             1
# 1320450          NaN          443.0           0             0             1
# 1320451          NaN          443.0           0             0             1
# 1320452          NaN          443.0           0             0             1
# 1320453          NaN          443.0           0             0             1
#
#          role_tutor   planta_name  Unnamed: 11  Unnamed: 0_y  \
# 0                 0   ABP Bergara          NaN          2861
# 1                 0   ABP Bergara          NaN          2861
# 2                 0   ABP Bergara          NaN          2861
# 3                 0   ABP Bergara          NaN          2861
# 4                 0   ABP Bergara          NaN          2861
# ...             ...           ...          ...           ...
# 1320449           0  MT Aretxabal          NaN          2858
# 1320450           0  MT Aretxabal          NaN          2859
# 1320451           0  MT Aretxabal          NaN          2859
# 1320452           0  MT Aretxabal          NaN          2860
# 1320453           0  MT Aretxabal          NaN          2860
#
#               course_name  course_id                                category  \
# 0        TALDEEN LIDERGOA        268                              PERSONALES
# 1        TALDEEN LIDERGOA        268                              PERSONALES
# 2        TALDEEN LIDERGOA        268                              PERSONALES
# 3        TALDEEN LIDERGOA        268                              PERSONALES
# 4        TALDEEN LIDERGOA        268                              PERSONALES
# ...                   ...        ...                                     ...
# 1320449    SEMELLE H5 RSA        252  TÉCNICO / TECNOLÓGICO MT - REFERENCIAS
# 1320450    SEMELLE H5 RSA        252  TÉCNICO / TECNOLÓGICO MT - REFERENCIAS
# 1320451    SEMELLE H5 RSA        252  TÉCNICO / TECNOLÓGICO MT - REFERENCIAS
# 1320452    SEMELLE H5 RSA        252  TÉCNICO / TECNOLÓGICO MT - REFERENCIAS
# 1320453    SEMELLE H5 RSA        252  TÉCNICO / TECNOLÓGICO MT - REFERENCIAS
#
#                  actividad_name  grade                 time  Unnamed: 0_x  \
# 0                          TEST   10.0  2021-08-05 12:34:41          1266
# 1                          TEST   10.0  2021-08-05 12:34:41          1266
# 2                          TEST   10.0  2021-08-05 12:34:41          1266
# 3                          TEST   10.0  2021-08-05 12:34:41          1267
# 4                          TEST   10.0  2021-08-05 12:34:41          1267
# ...                         ...    ...                  ...           ...
# 1320449                    TEST    8.0  2021-10-15 07:25:44          8454
# 1320450  SEMELLE H5 RSA - Total    8.0  2021-10-15 07:25:44          8453
# 1320451  SEMELLE H5 RSA - Total    8.0  2021-10-15 07:25:44          8454
# 1320452              TEST FINAL    NaN                  NaN          8453
# 1320453              TEST FINAL    NaN                  NaN          8454
#
#           description                  timestamp  mdl_user_id_y  Unnamed: 0_y  \
# 0        Login SRM OK  2021-07-22T11:03:45+01:00             13             0
# 1        Login SRM OK  2021-07-22T11:03:45+01:00             13             1
# 2        Login SRM OK  2021-07-22T11:03:45+01:00             13             2
# 3        Login SRM OK  2021-08-05T12:33:20+01:00             13             0
# 4        Login SRM OK  2021-08-05T12:33:20+01:00             13             1
# ...               ...                        ...            ...           ...
# 1320449  Login SRM OK  2021-10-15T06:51:45+01:00            443           450
# 1320450  Login SRM OK  2021-10-15T06:21:58+01:00            443           450
# 1320451  Login SRM OK  2021-10-15T06:51:45+01:00            443           450
# 1320452  Login SRM OK  2021-10-15T06:21:58+01:00            443           450
# 1320453  Login SRM OK  2021-10-15T06:51:45+01:00            443           450
#
#          active_flag_y  category_id                date_enroll  \
# 0                    0            8  2020-05-04T00:00:00+01:00
# 1                    1            2  2021-07-22T00:00:00+01:00
# 2                    1            8  2021-09-08T00:00:00+01:00
# 3                    0            8  2020-05-04T00:00:00+01:00
# 4                    1            2  2021-07-22T00:00:00+01:00
# ...                ...          ...                        ...
# 1320449              1            5  2021-10-01T00:00:00+01:00
# 1320450              1            5  2021-10-01T00:00:00+01:00
# 1320451              1            5  2021-10-01T00:00:00+01:00
# 1320452              1            5  2021-10-01T00:00:00+01:00
# 1320453              1            5  2021-10-01T00:00:00+01:00
#
#                         enroll_end  program_id remarks  tutor_academico_id  \
# 0        2023-04-01T23:59:00+01:00          66     NaN                   0
# 1                              NaN         145     NaN                   0
# 2                              NaN         146     NaN                   0
# 3        2023-04-01T23:59:00+01:00          66     NaN                   0
# 4                              NaN         145     NaN                   0
# ...                            ...         ...     ...                 ...
# 1320449                        NaN         163     NaN                   0
# 1320450                        NaN         163     NaN                   0
# 1320451                        NaN         163     NaN                   0
# 1320452                        NaN         163     NaN                   0
# 1320453                        NaN         163     NaN                   0
#
#          tutor_empresa_id     category_name  \
# 0                     190  SOPORTE&OPERARIO
# 1                      50              DUAL
# 2                     110  SOPORTE&OPERARIO
# 3                     190  SOPORTE&OPERARIO
# 4                      50              DUAL
# ...                   ...               ...
# 1320449               285      ESPECIALISTA
# 1320450               285      ESPECIALISTA
# 1320451               285      ESPECIALISTA
# 1320452               285      ESPECIALISTA
# 1320453               285      ESPECIALISTA
#
#                                   program_name
# 0              Tratamiento Térmico ABP Bergara
# 1                                   pruebas_01
# 2                   Operario Control Final CBI
# 3              Tratamiento Térmico ABP Bergara
# 4                                   pruebas_01
# ...                                        ...
# 1320449  Maquinista Mecanizados Autogestión MT
# 1320450  Maquinista Mecanizados Autogestión MT
# 1320451  Maquinista Mecanizados Autogestión MT
# 1320452  Maquinista Mecanizados Autogestión MT
# 1320453  Maquinista Mecanizados Autogestión MT
#
# [1320454 rows x 35 columns]

# %%
#NO EJECUTAR
#1)QUIENES SON LOS TUTORES
INFORMACION_TUTORES=pd.merge(Usuarios,Tutores_perfil,on="user_id")

#INFORMACION SOBRE QUE CURSOS Y ACTIVIDADES HAN HEHCHO
JOIN1_1=pd.merge(Usuarios,Actividades,on="mdl_user_id") 
JOIN1_2=pd.merge(JOIN1_1,Accesos,on="user_id") #ASI YA TENEMOS CON USER ID Y HACEMOS LO QUE QUEREMOS E

#INFORMACION EN COMPLETO SOBRE USUARIOS (NOMBRE DE CURSOS, CALIFICACIONES...)
JOIN1_3=pd.merge(JOIN1_2,Cursos_en_Programas,on="user_id")
JOIN1_4=pd.merge(JOIN1_3,Conocimientos,on="user_id")
JOIN1_5=pd.merge(JOIN1_4,Programas,on="program_id")
JOIN1_6=pd.merge(JOIN1_5,Itinerarios,on="program_id") 
JOIN1_7=pd.merge(JOIN1_6,Acceso_1ero_ultimo,on="mdl_user_id")
JOIN1_8=pd.merge(JOIN1_7,Cursos,on="course_id")
DF_COMPLETO=pd.merge(JOIN1_8,Notas_Cursos,on="course_id")

#INFORMACION SOBRE TODO TIPO DE MODOS DE APRENDER
JOIN3_1=pd.merge(Itinerarios,Cursos_en_Programas,on="program_id")
JOIN5_1=pd.merge(JOIN4_1,Programas,on="program_id")
JOIN4_1=pd.merge(JOIN3_1,Conocimientos,on="conocimiento_id")
#Para juntarlo con cursos hay que meter si o si actividades y usuarios y despues eliminar columna
JOIN4_1=pd.merge(JOIN3_1,Actividades,on="conocimiento_id")
JOIN2_3=pd.merge(JOIN1_2,Usuarios,on="user_id")
JOIN8_1=pd.merge(JOIN7_1,Cursos,on="course_id")

#EDUCACION + LOS USUARIOS QUE LA ESTAN CURSANDO
JOIN6_1=pd.merge(JOIN5_1,Itinerarios,on="program_id")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-7975c378ee0f> in <module>
#       1 #AHORA HACER DE LOS USUARIOS APRENDICES JOIN LARGO
#       2 JOIN1=pd.merge(Usuarios,Conocimientos,on="user_id")
# ----> 3 JOIN2=pd.merge(JOIN1,Cursos_en_Programas,on="user_id")
#       4 JOIN3=pd.merge(JOIN2,Programas,on="program_id")
#       5 JOIN4=pd.merge(JOIN3,Itinerarios,on="program_id")
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     666             self.right_join_keys,
#     667             self.join_names,
# --> 668         ) = self._get_merge_keys()
#     669
#     670         # validate the merge keys dtypes. We may need to coerce
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#    1031                     if not is_rkey(rk):
#    1032                         if rk is not None:
# -> 1033                             right_keys.append(right._get_label_or_level_values(rk))
#    1034                         else:
#    1035                             # work-around for merge_asof(right_index=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1682             values = self.axes[axis].get_level_values(key)._values
#    1683         else:
# -> 1684             raise KeyError(key)
#    1685
#    1686         # Check for duplicates
#
# KeyError: 'user_id'

# %%
#No deja join global
df1 = pd.merge(Usuarios, Tutores_perfil, how='outer')
df2 = pd.merge(df1, Actividades, how='outer')
df3 = pd.merge(df2, Accesos, how='outer')
df4 = pd.merge(df3, Cursos_en_Programas, how='outer')
df5 = pd.merge(df4, Conocimientos, how='outer')
df6 = pd.merge(df5, Programas, how='outer')
df7 = pd.merge(df6, Itinearios, how='outer')
df8 = pd.merge(df7, Acceso_1ero_ultimo, how='outer')

# %%
df8
# Out:
#        Unnamed: 0  user_id useranonimo_name  active_flag language  \
# 0               0      3.0      username_03          1.0       es
# 1               0     10.0              NaN          NaN      NaN
# 2               0      NaN              NaN          NaN      NaN
# 3               0      NaN              NaN          NaN      NaN
# 4               0      3.0              NaN          0.0      NaN
# ...           ...      ...              ...          ...      ...
# 13965         367      NaN              NaN          NaN      NaN
# 13966         368      NaN              NaN          NaN      NaN
# 13967         369      NaN              NaN          NaN      NaN
# 13968         370      NaN              NaN          NaN      NaN
# 13969         371      NaN              NaN          NaN      NaN
#
#        last_access  mdl_user_id  role_admin  role_manager  role_student  \
# 0              NaN         13.0         0.0           0.0           1.0
# 1              NaN          NaN         NaN           NaN           NaN
# 2              NaN          NaN         NaN           NaN           NaN
# 3              NaN          NaN         NaN           NaN           NaN
# 4              NaN          NaN         NaN           NaN           NaN
# ...            ...          ...         ...           ...           ...
# 13965          NaN        457.0         NaN           NaN           NaN
# 13966          NaN        458.0         NaN           NaN           NaN
# 13967          NaN        459.0         NaN           NaN           NaN
# 13968          NaN        460.0         NaN           NaN           NaN
# 13969          NaN        461.0         NaN           NaN           NaN
#
#        role_tutor  planta_name  Unnamed: 11  perfil_id        perfil_name  \
# 0             0.0  ABP Bergara          NaN        NaN                NaN
# 1             NaN          NaN          NaN        3.0  Gestor de empresa
# 2             NaN          NaN          NaN        NaN                NaN
# 3             NaN          NaN          NaN        NaN                NaN
# 4             NaN          NaN          NaN        NaN                NaN
# ...           ...          ...          ...        ...                ...
# 13965         NaN          NaN          NaN        NaN                NaN
# 13966         NaN          NaN          NaN        NaN                NaN
# 13967         NaN          NaN          NaN        NaN                NaN
# 13968         NaN          NaN          NaN        NaN                NaN
# 13969         NaN          NaN          NaN        NaN                NaN
#
#       course_name  course_id category actividad_name  grade time description  \
# 0             NaN        NaN      NaN            NaN    NaN  NaN         NaN
# 1             NaN        NaN      NaN            NaN    NaN  NaN         NaN
# 2             NaN        NaN      NaN            NaN    NaN  NaN         NaN
# 3             NaN        NaN      NaN            NaN    NaN  NaN         NaN
# 4             NaN        NaN      NaN            NaN    NaN  NaN         NaN
# ...           ...        ...      ...            ...    ...  ...         ...
# 13965         NaN        NaN      NaN            NaN    NaN  NaN         NaN
# 13966         NaN        NaN      NaN            NaN    NaN  NaN         NaN
# 13967         NaN        NaN      NaN            NaN    NaN  NaN         NaN
# 13968         NaN        NaN      NaN            NaN    NaN  NaN         NaN
# 13969         NaN        NaN      NaN            NaN    NaN  NaN         NaN
#
#       timestamp  program_course_online_id  course_moodle_id  conocimiento_id  \
# 0           NaN                    5717.0              72.0             24.0
# 1           NaN                    5717.0              72.0             24.0
# 2           NaN                       NaN               NaN            161.0
# 3           NaN                       NaN               NaN              NaN
# 4           NaN                       NaN               NaN              NaN
# ...         ...                       ...               ...              ...
# 13965       NaN                       NaN               NaN              NaN
# 13966       NaN                       NaN               NaN              NaN
# 13967       NaN                       NaN               NaN              NaN
# 13968       NaN                       NaN               NaN              NaN
# 13969       NaN                       NaN               NaN              NaN
#
#        num_periodo  program_id            course_moodle_id.1  \
# 0              1.0       187.0  INTRODUCCIÓN EN PRL Y MA ABP
# 1              1.0       187.0  INTRODUCCIÓN EN PRL Y MA ABP
# 2              NaN         NaN                           NaN
# 3              NaN        60.0                           NaN
# 4              NaN        66.0                           NaN
# ...            ...         ...                           ...
# 13965          NaN         NaN                           NaN
# 13966          NaN         NaN                           NaN
# 13967          NaN         NaN                           NaN
# 13968          NaN         NaN                           NaN
# 13969          NaN         NaN                           NaN
#
#                    conocimiento_name                     program_name color  \
# 0      ACOGIDA PRL Y MEDIO AMBIENTE              Control Visual Bruto   NaN
# 1      ACOGIDA PRL Y MEDIO AMBIENTE              Control Visual Bruto   NaN
# 2                               35UP                              NaN   NaN
# 3                                NaN         ITI CICLO DUAL 2019-2020   NaN
# 4                                NaN  Tratamiento Térmico ABP Bergara   NaN
# ...                              ...                              ...   ...
# 13965                            NaN                              NaN   NaN
# 13966                            NaN                              NaN   NaN
# 13967                            NaN                              NaN   NaN
# 13968                            NaN                              NaN   NaN
# 13969                            NaN                              NaN   NaN
#
#        created_by  categoria_conocimiento_id referencia  \
# 0             NaN                        NaN        NaN
# 1             NaN                        NaN        NaN
# 2           134.0                      158.0        NaN
# 3             NaN                        NaN        NaN
# 4             NaN                        NaN        NaN
# ...           ...                        ...        ...
# 13965         NaN                        NaN        NaN
# 13966         NaN                        NaN        NaN
# 13967         NaN                        NaN        NaN
# 13968         NaN                        NaN        NaN
# 13969         NaN                        NaN        NaN
#
#                categoria_conocimiento_name program_category_id  category_id  \
# 0                                      NaN                 NaN          NaN
# 1                                      NaN                 NaN          NaN
# 2      Técnico Tecnologico ABP Referencias                 NaN          NaN
# 3                                      NaN                DUAL          NaN
# 4                                      NaN                 NaN          8.0
# ...                                    ...                 ...          ...
# 13965                                  NaN                 NaN          NaN
# 13966                                  NaN                 NaN          NaN
# 13967                                  NaN                 NaN          NaN
# 13968                                  NaN                 NaN          NaN
# 13969                                  NaN                 NaN          NaN
#
#                      date_enroll                 enroll_end remarks  \
# 0                            NaN                        NaN     NaN
# 1                            NaN                        NaN     NaN
# 2                            NaN                        NaN     NaN
# 3                            NaN                        NaN     NaN
# 4      2020-05-04T00:00:00+01:00  2023-04-01T23:59:00+01:00     NaN
# ...                          ...                        ...     ...
# 13965                        NaN                        NaN     NaN
# 13966                        NaN                        NaN     NaN
# 13967                        NaN                        NaN     NaN
# 13968                        NaN                        NaN     NaN
# 13969                        NaN                        NaN     NaN
#
#        tutor_academico_id  tutor_empresa_id     category_name  \
# 0                     NaN               NaN               NaN
# 1                     NaN               NaN               NaN
# 2                     NaN               NaN               NaN
# 3                     NaN               NaN               NaN
# 4                     0.0             190.0  SOPORTE&OPERARIO
# ...                   ...               ...               ...
# 13965                 NaN               NaN               NaN
# 13966                 NaN               NaN               NaN
# 13967                 NaN               NaN               NaN
# 13968                 NaN               NaN               NaN
# 13969                 NaN               NaN               NaN
#
#                                  1er acceso  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 13965                                    --
# 13966                                    --
# 13967                                    --
# 13968                                    --
# 13969  jueves, 28 de octubre de 2021, 15:43
#
#                               ultimo acceso
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 13965                                    --
# 13966                                    --
# 13967                                    --
# 13968                                    --
# 13969  jueves, 28 de octubre de 2021, 16:03
#
# [13970 rows x 46 columns]

# %%
#Actividades, cursos en programas, cursos, programas, conocimientos
EDUCACION=pd.merge(Cursos_en_Programas,Programas,on="mdl_user_id") 
EDUCACION=pd.merge(EDUCACION,Conocimientos,on="conocimiento_id") 
EDUCACION=pd.merge(EDUCACION,Notas,on="conocimiento_id")
# Out:
#         Unnamed: 0_x  user_id useranonimo_name  active_flag language  \
# 0                  0        3      username_03            1       es
# 1                  0        3      username_03            1       es
# 2                  0        3      username_03            1       es
# 3                  0        3      username_03            1       es
# 4                  0        3      username_03            1       es
# ...              ...      ...              ...          ...      ...
# 286794           405      422     username_422            1       es
# 286795           405      422     username_422            1       es
# 286796           405      422     username_422            1       es
# 286797           405      422     username_422            1       es
# 286798           405      422     username_422            1       es
#
#         last_access  mdl_user_id_x  role_admin  role_manager  role_student  \
# 0               NaN           13.0           0             0             1
# 1               NaN           13.0           0             0             1
# 2               NaN           13.0           0             0             1
# 3               NaN           13.0           0             0             1
# 4               NaN           13.0           0             0             1
# ...             ...            ...         ...           ...           ...
# 286794          NaN          443.0           0             0             1
# 286795          NaN          443.0           0             0             1
# 286796          NaN          443.0           0             0             1
# 286797          NaN          443.0           0             0             1
# 286798          NaN          443.0           0             0             1
#
#         role_tutor   planta_name  Unnamed: 11  Unnamed: 0_y       course_name  \
# 0                0   ABP Bergara          NaN          2861  TALDEEN LIDERGOA
# 1                0   ABP Bergara          NaN          2861  TALDEEN LIDERGOA
# 2                0   ABP Bergara          NaN          2861  TALDEEN LIDERGOA
# 3                0   ABP Bergara          NaN          2862  TALDEEN LIDERGOA
# 4                0   ABP Bergara          NaN          2862  TALDEEN LIDERGOA
# ...            ...           ...          ...           ...               ...
# 286794           0  MT Aretxabal          NaN          2858    SEMELLE H5 RSA
# 286795           0  MT Aretxabal          NaN          2859    SEMELLE H5 RSA
# 286796           0  MT Aretxabal          NaN          2859    SEMELLE H5 RSA
# 286797           0  MT Aretxabal          NaN          2860    SEMELLE H5 RSA
# 286798           0  MT Aretxabal          NaN          2860    SEMELLE H5 RSA
#
#         course_id                                category  \
# 0             268                              PERSONALES
# 1             268                              PERSONALES
# 2             268                              PERSONALES
# 3             268                              PERSONALES
# 4             268                              PERSONALES
# ...           ...                                     ...
# 286794        252  TÉCNICO / TECNOLÓGICO MT - REFERENCIAS
# 286795        252  TÉCNICO / TECNOLÓGICO MT - REFERENCIAS
# 286796        252  TÉCNICO / TECNOLÓGICO MT - REFERENCIAS
# 286797        252  TÉCNICO / TECNOLÓGICO MT - REFERENCIAS
# 286798        252  TÉCNICO / TECNOLÓGICO MT - REFERENCIAS
#
#                   actividad_name  grade                 time  Unnamed: 0  \
# 0                           TEST   10.0  2021-08-05 12:34:41        1266
# 1                           TEST   10.0  2021-08-05 12:34:41        1267
# 2                           TEST   10.0  2021-08-05 12:34:41        1268
# 3       TALDEEN LIDERGOA - Total   10.0  2021-08-05 12:34:41        1266
# 4       TALDEEN LIDERGOA - Total   10.0  2021-08-05 12:34:41        1267
# ...                          ...    ...                  ...         ...
# 286794                      TEST    8.0  2021-10-15 07:25:44        8454
# 286795    SEMELLE H5 RSA - Total    8.0  2021-10-15 07:25:44        8453
# 286796    SEMELLE H5 RSA - Total    8.0  2021-10-15 07:25:44        8454
# 286797                TEST FINAL    NaN                  NaN        8453
# 286798                TEST FINAL    NaN                  NaN        8454
#
#          description                  timestamp  mdl_user_id_y
# 0       Login SRM OK  2021-07-22T11:03:45+01:00             13
# 1       Login SRM OK  2021-08-05T12:33:20+01:00             13
# 2       Login SRM OK  2021-10-28T13:27:59+01:00             13
# 3       Login SRM OK  2021-07-22T11:03:45+01:00             13
# 4       Login SRM OK  2021-08-05T12:33:20+01:00             13
# ...              ...                        ...            ...
# 286794  Login SRM OK  2021-10-15T06:51:45+01:00            443
# 286795  Login SRM OK  2021-10-15T06:21:58+01:00            443
# 286796  Login SRM OK  2021-10-15T06:51:45+01:00            443
# 286797  Login SRM OK  2021-10-15T06:21:58+01:00            443
# 286798  Login SRM OK  2021-10-15T06:51:45+01:00            443
#
# [286799 rows x 24 columns]

# %% [markdown]
# LIMPIEZA DE DATOS

# %%
Usuarios = pd.read_csv('UsuariosSheet.csv')
Tutores_perfil = pd.read_csv('Tutores_perfilSheet.csv')
Conocimientos = pd.read_csv('ConocimientosSheet.csv')
Cursos = pd.read_csv('CursosSheet.csv')
Programas = pd.read_csv('ProgramasSheet.csv')
Cursos_en_Programas = pd.read_csv('Cursos_en_ProgramasSheet.csv')
Itinearios = pd.read_csv('ItineariosSheet.csv')
Notas_Cursos = pd.read_csv('Notas_CursosSheet.csv')
Roles = pd.read_csv('RolesSheet.csv')
Plantas = pd.read_csv('PlantasSheet.csv')
Accesos = pd.read_csv('AccesosSheet.csv')
Acceso_1ero_ultimo = pd.read_csv('Acceso_1ero_ultimoSheet.csv')
Actividades = pd.read_csv('ActividadesSheet.csv')

# %%
Usuarios
# Out:
#      user_id  active_flag language  mdl_user_id  role_admin  role_manager  \
# 0          3            1       es         13.0           0             0
# 1          4            1       es         14.0           0             0
# 2          5            1       es         15.0           0             0
# 3          6            1       es         17.0           0             0
# 4          7            1       es         18.0           0             0
# ..       ...          ...      ...          ...         ...           ...
# 415      432            1       es        457.0           0             0
# 416      433            1       es        458.0           0             0
# 417      434            1       es        459.0           0             0
# 418      435            1       es        460.0           0             0
# 419      436            1       es        461.0           0             1
#
#      role_student  role_tutor      planta_name
# 0               1           0      ABP Bergara
# 1               1           0     Fagorederlan
# 2               1           0     ABP Arrasate
# 3               1           0     Fagorederlan
# 4               1           0     ABP Arrasate
# ..            ...         ...              ...
# 415             1           0  MT Aretxabaleta
# 416             1           0  MT Aretxabaleta
# 417             1           0  MT Aretxabaleta
# 418             1           0  MT Aretxabaleta
# 419             1           1      ABP Bergara
#
# [420 rows x 9 columns]

# %%
#Nombre de columnas
Usuarios.columns
# Out:
# Index(['user_id', 'active_flag', 'language', 'last_access', 'mdl_user_id',
#        'role_admin', 'role_manager', 'role_student', 'role_tutor',
#        'planta_name'],
#       dtype='object')

# %%
#Numero de columnas/filas
Usuarios.shape
# Out:
# (420, 10)

# %%
#Eliminar columnas innecesarias
Usuarios=Usuarios.drop(['Unnamed: 0'], axis=1)
Usuarios=Usuarios.drop(['Unnamed: 11'], axis=1)
Usuarios=Usuarios.drop(['useranonimo_name'], axis=1)
Usuarios=Usuarios.drop(['last_access'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-c92a8c383678> in <module>
#       1 #Eliminar columnas innecesarias
# ----> 2 Usuarios=Usuarios.drop(['Unnamed: 0'], axis=1)
#       3 Usuarios=Usuarios.drop(['Unnamed: 11'], axis=1)
#       4 Usuarios=Usuarios.drop(['useranonimo_name'], axis=1)
#       5 Usuarios=Usuarios.drop(['last_access'], axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4186                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4187             else:
# -> 4188                 new_axis = axis.drop(labels, errors=errors)
#    4189             result = self.reindex(**{axis_name: new_axis})
#    4190
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['Unnamed: 0'] not found in axis"

# %%
Usuarios.info
# Out:
# <bound method DataFrame.info of      user_id  active_flag language  last_access  mdl_user_id  role_admin  \
# 0          3            1       es          NaN         13.0           0
# 1          4            1       es          NaN         14.0           0
# 2          5            1       es          NaN         15.0           0
# 3          6            1       es          NaN         17.0           0
# 4          7            1       es          NaN         18.0           0
# ..       ...          ...      ...          ...          ...         ...
# 415      432            1       es          NaN        457.0           0
# 416      433            1       es          NaN        458.0           0
# 417      434            1       es          NaN        459.0           0
# 418      435            1       es          NaN        460.0           0
# 419      436            1       es          NaN        461.0           0
#
#      role_manager  role_student  role_tutor      planta_name
# 0               0             1           0      ABP Bergara
# 1               0             1           0     Fagorederlan
# 2               0             1           0     ABP Arrasate
# 3               0             1           0     Fagorederlan
# 4               0             1           0     ABP Arrasate
# ..            ...           ...         ...              ...
# 415             0             1           0  MT Aretxabaleta
# 416             0             1           0  MT Aretxabaleta
# 417             0             1           0  MT Aretxabaleta
# 418             0             1           0  MT Aretxabaleta
# 419             1             1           1      ABP Bergara
#
# [420 rows x 10 columns]>

# %%
#Tipos de variables
Usuarios.dtypes
# Out:
# user_id           int64
# active_flag       int64
# language         object
# mdl_user_id     float64
# role_admin        int64
# role_manager      int64
# role_student      int64
# role_tutor        int64
# planta_name      object
# dtype: object

# %%
Uusarios["mdl_user_id"]pd.to_numeric(Usuarios["mdl_user_id"])
# Out:
#   File "<ipython-input-65-531fc9823cb2>", line 1
#     Uusarios["mdl_user_id"]pd.to_numeric(Usuarios.mdl_user_id)
#                            ^
# SyntaxError: invalid syntax

# %%
#Duplicados
Usuarios.duplicated().sum() # busca duplicados de fila completa
# Out:
# 0

# %%
#NA'S
Usuarios.isna()
#Eliminamos last_acceses por %100 de NA'S 
Usuarios.isna().sum()
# Out:
# user_id           0
# active_flag       0
# language          0
# last_access     420
# mdl_user_id      15
# role_admin        0
# role_manager      0
# role_student      0
# role_tutor        0
# planta_name       0
# dtype: int64

# %%
#Se quitan o no 15 mdl_user_id en caso de que no necesitemos la variable
Usuarios.dropna(subset = ['mdl_user_id'])
# Out:
#      user_id  active_flag language  mdl_user_id  role_admin  role_manager  \
# 0          3            1       es         13.0           0             0
# 1          4            1       es         14.0           0             0
# 2          5            1       es         15.0           0             0
# 3          6            1       es         17.0           0             0
# 4          7            1       es         18.0           0             0
# ..       ...          ...      ...          ...         ...           ...
# 415      432            1       es        457.0           0             0
# 416      433            1       es        458.0           0             0
# 417      434            1       es        459.0           0             0
# 418      435            1       es        460.0           0             0
# 419      436            1       es        461.0           0             1
#
#      role_student  role_tutor      planta_name
# 0               1           0      ABP Bergara
# 1               1           0     Fagorederlan
# 2               1           0     ABP Arrasate
# 3               1           0     Fagorederlan
# 4               1           0     ABP Arrasate
# ..            ...         ...              ...
# 415             1           0  MT Aretxabaleta
# 416             1           0  MT Aretxabaleta
# 417             1           0  MT Aretxabaleta
# 418             1           0  MT Aretxabaleta
# 419             1           1      ABP Bergara
#
# [405 rows x 9 columns]

# %%
Tutores_perfil

# %%
Conocimientos

# %%
Cursos

# %%
Programas

# %%
Cursos_en_Programas

# %%
Itinearios

# %%
Notas_Cursos

# %%
Roles

# %%
Plantas

# %%
Accesos

# %%
Acceso_1ero_ultimo

# %%
Actividades
