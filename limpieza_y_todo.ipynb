# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
pd.options.display.max_columns = None

# %%
df = pd.read_excel('EDERJAKIN_LA_Datos_2021.xlsm', sheet_name=None)

# %%
#for sheet_name in list(df.keys()):
 #  df[sheet_name].to_csv(sheet_name + 'Sheet.csv')

# %%
Usuarios = pd.read_csv('UsuariosSheet.csv')
Tutores_perfil = pd.read_csv('Tutores perfilSheet.csv')
Conocimientos = pd.read_csv('ConocimientosSheet.csv')
Cursos = pd.read_csv('CursosSheet.csv')
Programas = pd.read_csv('ProgramasSheet.csv')
Cursos_en_Programas = pd.read_csv('Cursos en ProgramasSheet.csv')
Itinearios = pd.read_csv('ItineariosSheet.csv')
Notas_Cursos = pd.read_csv('Notas_CursosSheet.csv')
Roles = pd.read_csv('RolesSheet.csv')
Plantas = pd.read_csv('PlantasSheet.csv')
Accesos = pd.read_csv('AccesosSheet.csv')
Acceso_1ero_ultimo = pd.read_csv('Acceso_1ero_ultimoSheet.csv')
Actividades = pd.read_csv('ActividadesSheet.csv')

# %%
Usuarios
# Out:
#      Unnamed: 0  user_id useranonimo_name  active_flag language  last_access  \
# 0             0        3      username_03            1       es          NaN
# 1             1        4      username_04            1       es          NaN
# 2             2        5      username_05            1       es          NaN
# 3             3        6      username_06            1       es          NaN
# 4             4        7      username_07            1       es          NaN
# ..          ...      ...              ...          ...      ...          ...
# 415         415      432     username_432            1       es          NaN
# 416         416      433     username_433            1       es          NaN
# 417         417      434     username_434            1       es          NaN
# 418         418      435     username_435            1       es          NaN
# 419         419      436     username_436            1       es          NaN
#
#      mdl_user_id  role_admin  role_manager  role_student  role_tutor  \
# 0           13.0           0             0             1           0
# 1           14.0           0             0             1           0
# 2           15.0           0             0             1           0
# 3           17.0           0             0             1           0
# 4           18.0           0             0             1           0
# ..           ...         ...           ...           ...         ...
# 415        457.0           0             0             1           0
# 416        458.0           0             0             1           0
# 417        459.0           0             0             1           0
# 418        460.0           0             0             1           0
# 419        461.0           0             1             1           1
#
#          planta_name  Unnamed: 11
# 0        ABP Bergara          NaN
# 1       Fagorederlan          NaN
# 2       ABP Arrasate          NaN
# 3       Fagorederlan          NaN
# 4       ABP Arrasate          NaN
# ..               ...          ...
# 415  MT Aretxabaleta          NaN
# 416  MT Aretxabaleta          NaN
# 417  MT Aretxabaleta          NaN
# 418  MT Aretxabaleta          NaN
# 419      ABP Bergara          NaN
#
# [420 rows x 13 columns]

# %%
#Nombre de columnas
Usuarios.columns
# Out:
# Index(['Unnamed: 0', 'user_id', 'useranonimo_name', 'active_flag', 'language',
#        'last_access', 'mdl_user_id', 'role_admin', 'role_manager',
#        'role_student', 'role_tutor', 'planta_name', 'Unnamed: 11'],
#       dtype='object')

# %%
#Numero de columnas/filas
Usuarios.shape
# Out:
# (420, 13)

# %%
Usuarios.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0  user_id useranonimo_name  active_flag language  last_access  \
# 0             0        3      username_03            1       es          NaN
# 1             1        4      username_04            1       es          NaN
# 2             2        5      username_05            1       es          NaN
# 3             3        6      username_06            1       es          NaN
# 4             4        7      username_07            1       es          NaN
# ..          ...      ...              ...          ...      ...          ...
# 415         415      432     username_432            1       es          NaN
# 416         416      433     username_433            1       es          NaN
# 417         417      434     username_434            1       es          NaN
# 418         418      435     username_435            1       es          NaN
# 419         419      436     username_436            1       es          NaN
#
#      mdl_user_id  role_admin  role_manager  role_student  role_tutor  \
# 0           13.0           0             0             1           0
# 1           14.0           0             0             1           0
# 2           15.0           0             0             1           0
# 3           17.0           0             0             1           0
# 4           18.0           0             0             1           0
# ..           ...         ...           ...           ...         ...
# 415        457.0           0             0             1           0
# 416        458.0           0             0             1           0
# 417        459.0           0             0             1           0
# 418        460.0           0             0             1           0
# 419        461.0           0             1             1           1
#
#          planta_name  Unnamed: 11
# 0        ABP Bergara          NaN
# 1       Fagorederlan          NaN
# 2       ABP Arrasate          NaN
# 3       Fagorederlan          NaN
# 4       ABP Arrasate          NaN
# ..               ...          ...
# 415  MT Aretxabaleta          NaN
# 416  MT Aretxabaleta          NaN
# 417  MT Aretxabaleta          NaN
# 418  MT Aretxabaleta          NaN
# 419      ABP Bergara          NaN
#
# [420 rows x 13 columns]>

# %%
#Tipos de variables
Usuarios.dtypes
# Out:
# Unnamed: 0            int64
# user_id               int64
# useranonimo_name     object
# active_flag           int64
# language             object
# last_access         float64
# mdl_user_id         float64
# role_admin            int64
# role_manager          int64
# role_student          int64
# role_tutor            int64
# planta_name          object
# Unnamed: 11         float64
# dtype: object

# %%
#Duplicados
Usuarios.duplicated().sum() # busca duplicados de fila completa
# Out:
# 0

# %%
#NA'S
Usuarios.isna()
#Eliminamos last_acceses por %100 de NA'S 
Usuarios.isna().sum()
# Out:
# Unnamed: 0            0
# user_id               0
# useranonimo_name      0
# active_flag           0
# language              0
# last_access         420
# mdl_user_id          15
# role_admin            0
# role_manager          0
# role_student          0
# role_tutor            0
# planta_name           0
# Unnamed: 11         420
# dtype: int64

# %%
#Se quitan o no 15 mdl_user_id en caso de que no necesitemos la variable
Usuarios=Usuarios.dropna(subset = ['mdl_user_id'])

# %%
Usuarios=Usuarios.drop(['Unnamed: 0'], axis=1)

# %%
Tutores_perfil
# Out:
#      Unnamed: 0  perfil_id  user_id        perfil_name
# 0             0          3       10  Gestor de empresa
# 1             1          3       41  Gestor de empresa
# 2             2          3       42  Gestor de empresa
# 3             3          3      110  Gestor de empresa
# 4             4          3      115  Gestor de empresa
# ..          ...        ...      ...                ...
# 183         183          0      358                NaN
# 184         184          0      369                NaN
# 185         185          0      379                NaN
# 186         186          0      415                NaN
# 187         187          0      423                NaN
#
# [188 rows x 4 columns]

# %%
Tutores_perfil.columns
# Out:
# Index(['Unnamed: 0', 'perfil_id', 'user_id', 'perfil_name'], dtype='object')

# %%
Tutores_perfil=Tutores_perfil.drop(['Unnamed: 0'], axis=1)

# %%
#Tipos de variables
Tutores_perfil.dtypes
# Out:
# perfil_id       int64
# user_id         int64
# perfil_name    object
# dtype: object

# %%
#Duplicados
Tutores_perfil.duplicated().sum() # busca duplicados de fila completa
# Out:
# 0

# %%
#NA'S
Tutores_perfil.isna()
#Eliminamos last_acceses por %100 de NA'S 
Tutores_perfil.isna().sum()
# Out:
# perfil_id       0
# user_id         0
# perfil_name    70
# dtype: int64

# %%
Tutores_perfil.shape
# Out:
# (188, 3)

# %%
Tutores_perfil = Tutores_perfil.fillna("Tutores basicos")

# %%
Tutores_perfil
# Out:
#      perfil_id  user_id        perfil_name
# 0            3       10  Gestor de empresa
# 1            3       41  Gestor de empresa
# 2            3       42  Gestor de empresa
# 3            3      110  Gestor de empresa
# 4            3      115  Gestor de empresa
# ..         ...      ...                ...
# 183          0      358    Tutores basicos
# 184          0      369    Tutores basicos
# 185          0      379    Tutores basicos
# 186          0      415    Tutores basicos
# 187          0      423    Tutores basicos
#
# [188 rows x 3 columns]

# %%
Conocimientos
# Out:
#      Unnamed: 0  conocimiento_id              conocimiento_name    color  \
# 0             0              161                           35UP      NaN
# 1             1               21                            ABP  #ff4c05
# 2             2              157       ACABADO - Control Visual      NaN
# 3             3               42  ACABADO - Tratamiento Térmico      NaN
# 4             4               90    ACABADO_Tratamiento Térmico      NaN
# ..          ...              ...                            ...      ...
# 150         150                8                  TECNICOS_DUAL      NaN
# 151         151              104              U_ACOGIDA GENERAL      NaN
# 152         152              106                   U_MECANIZADO      NaN
# 153         153              105                   U_SOCIETARIO      NaN
# 154         154              159                            UKL      NaN
#
#      created_by                        description  categoria_conocimiento_id  \
# 0           134                                NaN                        158
# 1           135                                NaN                          0
# 2           134                                NaN                         79
# 3           135                                NaN                         42
# 4           145                                NaN                         79
# ..          ...                                ...                        ...
# 150         132                                NaN                          5
# 151         190                                NaN                         11
# 152         190    (DESCRIPCION DEL CONOCIMIENTO?)                          7
# 153         190  U: (DESCRIPCION DEL CONOCIMIENTO)                         17
# 154         134                                NaN                        158
#
#     referencia          categoria_conocimiento_name
# 0          NaN  Técnico Tecnologico ABP Referencias
# 1          NaN                                  NaN
# 2          NaN            TÉCNICOS/TECNOLÓGICOS ABP
# 3          NaN        ACABADO - Tratamiento Térmico
# 4          NaN            TÉCNICOS/TECNOLÓGICOS ABP
# ..         ...                                  ...
# 150        NaN                                 DUAL
# 151        NaN                              ACOGIDA
# 152        NaN                             TÉCNICOS
# 153        NaN                          SOCIETARIOS
# 154        NaN  Técnico Tecnologico ABP Referencias
#
# [155 rows x 9 columns]

# %%
#Nombre de columnas
Conocimientos.columns
# Out:
# Index(['Unnamed: 0', 'conocimiento_id', 'conocimiento_name', 'color',
#        'created_by', 'description', 'categoria_conocimiento_id', 'referencia',
#        'categoria_conocimiento_name'],
#       dtype='object')

# %%
Conocimientos=Conocimientos.drop(['Unnamed: 0'], axis=1)
Conocimientos=Conocimientos.drop(['color'], axis=1)

# %%
#Tipos de variables
Conocimientos.dtypes
# Out:
# conocimiento_id                 int64
# conocimiento_name              object
# created_by                      int64
# description                    object
# categoria_conocimiento_id       int64
# referencia                     object
# categoria_conocimiento_name    object
# dtype: object

# %%
#Duplicados
Conocimientos.duplicated().sum() # busca duplicados de fila completa
# Out:
# 0

# %%
#NA'S
Conocimientos.isna()
#Eliminamos last_acceses por %100 de NA'S 
Conocimientos.isna().sum()
# Out:
# conocimiento_id                  0
# conocimiento_name                0
# created_by                       0
# description                    138
# categoria_conocimiento_id        0
# referencia                     122
# categoria_conocimiento_name     22
# dtype: int64

# %%
Conocimientos.shape
# Out:
# (155, 7)

# %%
Conocimientos=Conocimientos.drop(['description'], axis=1)
Conocimientos=Conocimientos.drop(['referencia'], axis=1)

# %%
Conocimientos = Conocimientos.fillna("Sin asignar")

# %%
Cursos
# Out:
#      Unnamed: 0  course_id                             course_name  category  \
# 0             0          1                  EDERJakin FagorEDERLAN         0
# 1             1          2           ITINERARIO GRADO DUAL 2018/19         3
# 2             2          6           ITINERARIO CICLO DUAL 2018/19         3
# 3             3          9        TEC_01 - PRODUCTOS FAGOR EDERLAN         3
# 4             4         10           TEC_02 - PROCESOS PRODUCTIVOS         3
# ..          ...        ...                                     ...       ...
# 134         134        303  CONTROL VISUAL MEC - MLA IKUS KONTROLA        27
# 135         135        304   CONTROL VISUAL MEC - BR IKUS KONTROLA        27
# 136         136        305                CONTROL VISUAL MEC - UKL        27
# 137         137        306                              CURSO UXUE        27
# 138         138        307            FUSIOA ABP - FUSIO DORREA N2        27
#
#      hours      course_shortname  sortorder  \
# 0        0             EDERJAKIN          1
# 1        0  ITI_GRADO_DUAL_18/19      40016
# 2        0  ITI_CICLO_DUAL_18/19      40014
# 3        4                TEC_01      40022
# 4       20                TEC_02      40024
# ..     ...                   ...        ...
# 134      0      TEC_CVMEC_02_MLA     110003
# 135      0       TEC_CVMEC_02_BR     110002
# 136      0      TEC_CVMEC_01_UKL     110001
# 137      0          TEC_ABP_UXUE          0
# 138     40              _ALDATU_          0
#
#                                                summary
# 0                                                  NaN
# 1    Itinerario de Aprendizaje del GRADO DUAL en Fa...
# 2    Itinerario de Aprendizaje del CICLO DUAL en Fa...
# 3    Conocer los PRODUCTOS fabricados de Fagor EDERLAN
# 4    Conocer los PROCESOS PRODUCTIVOS de Fagor EDERLAN
# ..                                                 ...
# 134                                                NaN
# 135                                                NaN
# 136                                                NaN
# 137                                                NaN
# 138                                                NaN
#
# [139 rows x 8 columns]

# %%
#Nombre de columnas
Cursos.columns
# Out:
# Index(['Unnamed: 0', 'course_id', 'course_name', 'category', 'hours',
#        'course_shortname', 'sortorder', 'summary'],
#       dtype='object')

# %%
Cursos=Cursos.drop("course_shortname",axis=1)
Cursos=Cursos.drop("Unnamed: 0",axis=1)

# %%
#Tipos de variables
Cursos.dtypes
# Out:
# course_id       int64
# course_name    object
# category        int64
# hours           int64
# sortorder       int64
# summary        object
# dtype: object

# %%
#Duplicados
Cursos.duplicated().sum() # busca duplicados de fila completa
# Out:
# 0

# %%
Cursos.shape
# Out:
# (139, 6)

# %%
#NA'S
Cursos.isna()
#Eliminamos last_acceses por %100 de NA'S 
Cursos.isna().sum()
# Out:
# course_id       0
# course_name     0
# category        0
# hours           0
# sortorder       0
# summary        95
# dtype: int64

# %%
Cursos = Cursos.fillna("No especificado")

# %%
Cursos = Cursos.rename(columns={'category':'category_curso_id'})

# %%
Programas
# Out:
#      Unnamed: 0  program_id                       program_name  \
# 0             0          60           ITI CICLO DUAL 2019-2020
# 1             1          61                    Programa PILOTO
# 2             2          62  Maquinista Mecanizado ABP Bergara
# 3             3          63                             nvnvbn
# 4             4          64           ITI GRADO DUAL 2019-2020
# ..          ...         ...                                ...
# 105         105         184       Maquinista Mecanizados LPPFe
# 106         106         185           Operario de Macheria LPC
# 107         107         186                        PERTSONALAK
# 108         108         187               Control Visual Bruto
# 109         109         188             Control Visual Mec ABP
#
#     program_category_id
# 0                  DUAL
# 1               TÉCNICO
# 2               TÉCNICO
# 3                  DUAL
# 4                  DUAL
# ..                  ...
# 105        ESPECIALISTA
# 106    SOPORTE&OPERARIO
# 107             GESTIÓN
# 108    SOPORTE&OPERARIO
# 109    SOPORTE&OPERARIO
#
# [110 rows x 4 columns]

# %%
#Nombre de columnas
Programas.columns
# Out:
# Index(['Unnamed: 0', 'program_id', 'program_name', 'program_category_id'], dtype='object')

# %%
#Numero de columnas/filas
Programas.shape
# Out:
# (110, 4)

# %%
Programas.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0  program_id                       program_name  \
# 0             0          60           ITI CICLO DUAL 2019-2020
# 1             1          61                    Programa PILOTO
# 2             2          62  Maquinista Mecanizado ABP Bergara
# 3             3          63                             nvnvbn
# 4             4          64           ITI GRADO DUAL 2019-2020
# ..          ...         ...                                ...
# 105         105         184       Maquinista Mecanizados LPPFe
# 106         106         185           Operario de Macheria LPC
# 107         107         186                        PERTSONALAK
# 108         108         187               Control Visual Bruto
# 109         109         188             Control Visual Mec ABP
#
#     program_category_id
# 0                  DUAL
# 1               TÉCNICO
# 2               TÉCNICO
# 3                  DUAL
# 4                  DUAL
# ..                  ...
# 105        ESPECIALISTA
# 106    SOPORTE&OPERARIO
# 107             GESTIÓN
# 108    SOPORTE&OPERARIO
# 109    SOPORTE&OPERARIO
#
# [110 rows x 4 columns]>

# %%
#Tipos de variables
Programas.dtypes
# Out:
# Unnamed: 0              int64
# program_id              int64
# program_name           object
# program_category_id    object
# dtype: object

# %%
#Duplicados
Programas.duplicated().sum() # busca duplicados de fila completa
# Out:
# 0

# %%
#NA'S
Programas.isna()
Programas.isna().sum()
# Out:
# Unnamed: 0             0
# program_id             0
# program_name           0
# program_category_id    1
# dtype: int64

# %%
#Eliminamos la fila que contiene NA en program_category_id.
Programas=Programas.dropna(axis = 0, how = 'any') 
Programas.isna().sum()
# Out:
# Unnamed: 0             0
# program_id             0
# program_name           0
# program_category_id    0
# dtype: int64

# %%
#Eliminamos la columna 'Unnamed: 0' ya que no aporta valor.
Programas=Programas.drop(['Unnamed: 0'], axis=1)

# %%
Programas
# Out:
#      program_id                       program_name program_category_id
# 0            60           ITI CICLO DUAL 2019-2020                DUAL
# 1            61                    Programa PILOTO             TÉCNICO
# 2            62  Maquinista Mecanizado ABP Bergara             TÉCNICO
# 3            63                             nvnvbn                DUAL
# 4            64           ITI GRADO DUAL 2019-2020                DUAL
# ..          ...                                ...                 ...
# 105         184       Maquinista Mecanizados LPPFe        ESPECIALISTA
# 106         185           Operario de Macheria LPC    SOPORTE&OPERARIO
# 107         186                        PERTSONALAK             GESTIÓN
# 108         187               Control Visual Bruto    SOPORTE&OPERARIO
# 109         188             Control Visual Mec ABP    SOPORTE&OPERARIO
#
# [109 rows x 3 columns]

# %%
Cursos_en_Programas
# Out:
#      Unnamed: 0  program_course_online_id  course_moodle_id  conocimiento_id  \
# 0             0                      5717                72               24
# 1             1                      5718                70               20
# 2             2                      5719               297              157
# 3             3                      5723               298              165
# 4             4                      5724               299               40
# ..          ...                       ...               ...              ...
# 248         248                      5640                72               24
# 249         249                      5641                74               24
# 250         250                      5642                69               20
# 251         251                      5644                70               20
# 252         252                      5652               193               90
#
#      num_periodo  program_id  \
# 0              1         187
# 1              1         187
# 2              1         187
# 3              0         188
# 4              0         188
# ..           ...         ...
# 248            1          66
# 249            1          66
# 250            1          66
# 251            1          66
# 252            2          66
#
#                                     course_moodle_id.1  \
# 0                         INTRODUCCIÓN EN PRL Y MA ABP
# 1                                     PLAN ACOGIDA ABP
# 2    CONTROL VISUAL GENÉRICO - LANDUGABEA IKUS KONT...
# 3        CONTROL VISUAL MEC.  GENÉRICO - IKUS KONTROLA
# 4               CONTROL VISUAL MEC - G2X IKUS KONTROLA
# ..                                                 ...
# 248                       INTRODUCCIÓN EN PRL Y MA ABP
# 249                 EVALUACIÓN RIESGOS DEL PUESTO - TT
# 250                               PLAN ACOGIDA GENERAL
# 251                                   PLAN ACOGIDA ABP
# 252                       TRATAMIENTO TÉRMICO ABP B_N3
#
#                  conocimiento_name                     program_name
# 0    ACOGIDA PRL Y MEDIO AMBIENTE              Control Visual Bruto
# 1                  ACOGIDA GENERAL             Control Visual Bruto
# 2         ACABADO - Control Visual             Control Visual Bruto
# 3                       MECANIZADO           Control Visual Mec ABP
# 4                 MECANIZADO - G2X           Control Visual Mec ABP
# ..                             ...                              ...
# 248  ACOGIDA PRL Y MEDIO AMBIENTE   Tratamiento Térmico ABP Bergara
# 249  ACOGIDA PRL Y MEDIO AMBIENTE   Tratamiento Térmico ABP Bergara
# 250                ACOGIDA GENERAL  Tratamiento Térmico ABP Bergara
# 251                ACOGIDA GENERAL  Tratamiento Térmico ABP Bergara
# 252    ACABADO_Tratamiento Térmico  Tratamiento Térmico ABP Bergara
#
# [253 rows x 9 columns]

# %%
#Nombre de columnas
Cursos_en_Programas.columns
# Out:
# Index(['Unnamed: 0', 'program_course_online_id', 'course_moodle_id',
#        'conocimiento_id', 'num_periodo', 'program_id', 'course_moodle_id.1',
#        'conocimiento_name', 'program_name'],
#       dtype='object')

# %%
#Numero de columnas/filas
Cursos_en_Programas.shape
# Out:
# (253, 9)

# %%
Cursos_en_Programas.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0  program_course_online_id  course_moodle_id  conocimiento_id  \
# 0             0                      5717                72               24
# 1             1                      5718                70               20
# 2             2                      5719               297              157
# 3             3                      5723               298              165
# 4             4                      5724               299               40
# ..          ...                       ...               ...              ...
# 248         248                      5640                72               24
# 249         249                      5641                74               24
# 250         250                      5642                69               20
# 251         251                      5644                70               20
# 252         252                      5652               193               90
#
#      num_periodo  program_id  \
# 0              1         187
# 1              1         187
# 2              1         187
# 3              0         188
# 4              0         188
# ..           ...         ...
# 248            1          66
# 249            1          66
# 250            1          66
# 251            1          66
# 252            2          66
#
#                                     course_moodle_id.1  \
# 0                         INTRODUCCIÓN EN PRL Y MA ABP
# 1                                     PLAN ACOGIDA ABP
# 2    CONTROL VISUAL GENÉRICO - LANDUGABEA IKUS KONT...
# 3        CONTROL VISUAL MEC.  GENÉRICO - IKUS KONTROLA
# 4               CONTROL VISUAL MEC - G2X IKUS KONTROLA
# ..                                                 ...
# 248                       INTRODUCCIÓN EN PRL Y MA ABP
# 249                 EVALUACIÓN RIESGOS DEL PUESTO - TT
# 250                               PLAN ACOGIDA GENERAL
# 251                                   PLAN ACOGIDA ABP
# 252                       TRATAMIENTO TÉRMICO ABP B_N3
#
#                  conocimiento_name                     program_name
# 0    ACOGIDA PRL Y MEDIO AMBIENTE              Control Visual Bruto
# 1                  ACOGIDA GENERAL             Control Visual Bruto
# 2         ACABADO - Control Visual             Control Visual Bruto
# 3                       MECANIZADO           Control Visual Mec ABP
# 4                 MECANIZADO - G2X           Control Visual Mec ABP
# ..                             ...                              ...
# 248  ACOGIDA PRL Y MEDIO AMBIENTE   Tratamiento Térmico ABP Bergara
# 249  ACOGIDA PRL Y MEDIO AMBIENTE   Tratamiento Térmico ABP Bergara
# 250                ACOGIDA GENERAL  Tratamiento Térmico ABP Bergara
# 251                ACOGIDA GENERAL  Tratamiento Térmico ABP Bergara
# 252    ACABADO_Tratamiento Térmico  Tratamiento Térmico ABP Bergara
#
# [253 rows x 9 columns]>

# %%
Cursos_en_Programas.dtypes
# Out:
# Unnamed: 0                   int64
# program_course_online_id     int64
# course_moodle_id             int64
# conocimiento_id              int64
# num_periodo                  int64
# program_id                   int64
# course_moodle_id.1          object
# conocimiento_name           object
# program_name                object
# dtype: object

# %%
#Duplicados
Cursos_en_Programas.duplicated().sum() # busca duplicados de fila completa
# Out:
# 0

# %%
#NA'S
Cursos_en_Programas.isna()
Cursos_en_Programas.isna().sum()
# Out:
# Unnamed: 0                  0
# program_course_online_id    0
# course_moodle_id            0
# conocimiento_id             0
# num_periodo                 0
# program_id                  0
# course_moodle_id.1          0
# conocimiento_name           0
# program_name                0
# dtype: int64

# %%
#Eliminamos la columna 'Unnamed: 0' ya que no aporta valor.
Cursos_en_Programas=Cursos_en_Programas.drop(['Unnamed: 0'], axis=1)

# %%
Cursos_en_Programas
# Out:
#      program_course_online_id  course_moodle_id  conocimiento_id  num_periodo  \
# 0                        5717                72               24            1
# 1                        5718                70               20            1
# 2                        5719               297              157            1
# 3                        5723               298              165            0
# 4                        5724               299               40            0
# ..                        ...               ...              ...          ...
# 248                      5640                72               24            1
# 249                      5641                74               24            1
# 250                      5642                69               20            1
# 251                      5644                70               20            1
# 252                      5652               193               90            2
#
#      program_id                                 course_moodle_id.1  \
# 0           187                       INTRODUCCIÓN EN PRL Y MA ABP
# 1           187                                   PLAN ACOGIDA ABP
# 2           187  CONTROL VISUAL GENÉRICO - LANDUGABEA IKUS KONT...
# 3           188      CONTROL VISUAL MEC.  GENÉRICO - IKUS KONTROLA
# 4           188             CONTROL VISUAL MEC - G2X IKUS KONTROLA
# ..          ...                                                ...
# 248          66                       INTRODUCCIÓN EN PRL Y MA ABP
# 249          66                 EVALUACIÓN RIESGOS DEL PUESTO - TT
# 250          66                               PLAN ACOGIDA GENERAL
# 251          66                                   PLAN ACOGIDA ABP
# 252          66                       TRATAMIENTO TÉRMICO ABP B_N3
#
#                  conocimiento_name                     program_name
# 0    ACOGIDA PRL Y MEDIO AMBIENTE              Control Visual Bruto
# 1                  ACOGIDA GENERAL             Control Visual Bruto
# 2         ACABADO - Control Visual             Control Visual Bruto
# 3                       MECANIZADO           Control Visual Mec ABP
# 4                 MECANIZADO - G2X           Control Visual Mec ABP
# ..                             ...                              ...
# 248  ACOGIDA PRL Y MEDIO AMBIENTE   Tratamiento Térmico ABP Bergara
# 249  ACOGIDA PRL Y MEDIO AMBIENTE   Tratamiento Térmico ABP Bergara
# 250                ACOGIDA GENERAL  Tratamiento Térmico ABP Bergara
# 251                ACOGIDA GENERAL  Tratamiento Térmico ABP Bergara
# 252    ACABADO_Tratamiento Térmico  Tratamiento Térmico ABP Bergara
#
# [253 rows x 8 columns]

# %%
Itinearios
# Out:
#      Unnamed: 0  active_flag  category_id                date_enroll  \
# 0             0            0            8  2020-05-04T00:00:00+01:00
# 1             1            1            2  2021-07-22T00:00:00+01:00
# 2             2            1            8  2021-09-08T00:00:00+01:00
# 3             3            0            2  2020-06-18T00:00:00+01:00
# 4             4            0            2  2020-09-24T00:00:00+01:00
# ..          ...          ...          ...                        ...
# 462         462            1            5  2021-10-25T00:00:00+01:00
# 463         463            1            5  2021-10-25T00:00:00+01:00
# 464         464            1            5  2021-10-25T00:00:00+01:00
# 465         465            1            8  2021-10-28T00:00:00+01:00
# 466         466            1            8  2021-10-28T00:00:00+01:00
#
#                     enroll_end  program_id remarks  tutor_academico_id  \
# 0    2023-04-01T23:59:00+01:00          66     NaN                   0
# 1                          NaN         145     NaN                   0
# 2                          NaN         146     NaN                   0
# 3                          NaN          64     NaN                 148
# 4    2021-06-30T23:59:00+01:00         135     NaN                 148
# ..                         ...         ...     ...                 ...
# 462                        NaN         163     NaN                   0
# 463                        NaN         163     NaN                   0
# 464                        NaN         163     NaN                   0
# 465                        NaN          66     NaN                   0
# 466                        NaN         188     NaN                   0
#
#      tutor_empresa_id  user_id     category_name  \
# 0                 190        3  SOPORTE&OPERARIO
# 1                  50        3              DUAL
# 2                 110        3  SOPORTE&OPERARIO
# 3                  41        4              DUAL
# 4                  41        4              DUAL
# ..                ...      ...               ...
# 462               286      433      ESPECIALISTA
# 463               287      434      ESPECIALISTA
# 464               285      435      ESPECIALISTA
# 465               190      436  SOPORTE&OPERARIO
# 466               190      436  SOPORTE&OPERARIO
#
#                               program_name
# 0          Tratamiento Térmico ABP Bergara
# 1                               pruebas_01
# 2               Operario Control Final CBI
# 3                 ITI GRADO DUAL 2019-2020
# 4                 ITI GRADO DUAL 2020-2021
# ..                                     ...
# 462  Maquinista Mecanizados Autogestión MT
# 463  Maquinista Mecanizados Autogestión MT
# 464  Maquinista Mecanizados Autogestión MT
# 465        Tratamiento Térmico ABP Bergara
# 466                 Control Visual Mec ABP
#
# [467 rows x 12 columns]

# %%
#Nombre de columnas
Itinearios.columns
# Out:
# Index(['Unnamed: 0', 'active_flag', 'category_id', 'date_enroll', 'enroll_end',
#        'program_id', 'remarks', 'tutor_academico_id', 'tutor_empresa_id',
#        'user_id', 'category_name', 'program_name'],
#       dtype='object')

# %%
#Numero de columnas/filas
Itinearios.shape
# Out:
# (467, 12)

# %%
Itinearios.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0  active_flag  category_id                date_enroll  \
# 0             0            0            8  2020-05-04T00:00:00+01:00
# 1             1            1            2  2021-07-22T00:00:00+01:00
# 2             2            1            8  2021-09-08T00:00:00+01:00
# 3             3            0            2  2020-06-18T00:00:00+01:00
# 4             4            0            2  2020-09-24T00:00:00+01:00
# ..          ...          ...          ...                        ...
# 462         462            1            5  2021-10-25T00:00:00+01:00
# 463         463            1            5  2021-10-25T00:00:00+01:00
# 464         464            1            5  2021-10-25T00:00:00+01:00
# 465         465            1            8  2021-10-28T00:00:00+01:00
# 466         466            1            8  2021-10-28T00:00:00+01:00
#
#                     enroll_end  program_id remarks  tutor_academico_id  \
# 0    2023-04-01T23:59:00+01:00          66     NaN                   0
# 1                          NaN         145     NaN                   0
# 2                          NaN         146     NaN                   0
# 3                          NaN          64     NaN                 148
# 4    2021-06-30T23:59:00+01:00         135     NaN                 148
# ..                         ...         ...     ...                 ...
# 462                        NaN         163     NaN                   0
# 463                        NaN         163     NaN                   0
# 464                        NaN         163     NaN                   0
# 465                        NaN          66     NaN                   0
# 466                        NaN         188     NaN                   0
#
#      tutor_empresa_id  user_id     category_name  \
# 0                 190        3  SOPORTE&OPERARIO
# 1                  50        3              DUAL
# 2                 110        3  SOPORTE&OPERARIO
# 3                  41        4              DUAL
# 4                  41        4              DUAL
# ..                ...      ...               ...
# 462               286      433      ESPECIALISTA
# 463               287      434      ESPECIALISTA
# 464               285      435      ESPECIALISTA
# 465               190      436  SOPORTE&OPERARIO
# 466               190      436  SOPORTE&OPERARIO
#
#                               program_name
# 0          Tratamiento Térmico ABP Bergara
# 1                               pruebas_01
# 2               Operario Control Final CBI
# 3                 ITI GRADO DUAL 2019-2020
# 4                 ITI GRADO DUAL 2020-2021
# ..                                     ...
# 462  Maquinista Mecanizados Autogestión MT
# 463  Maquinista Mecanizados Autogestión MT
# 464  Maquinista Mecanizados Autogestión MT
# 465        Tratamiento Térmico ABP Bergara
# 466                 Control Visual Mec ABP
#
# [467 rows x 12 columns]>

# %%
#Tipos de variables
Itinearios.dtypes
# Out:
# Unnamed: 0             int64
# active_flag            int64
# category_id            int64
# date_enroll           object
# enroll_end            object
# program_id             int64
# remarks               object
# tutor_academico_id     int64
# tutor_empresa_id       int64
# user_id                int64
# category_name         object
# program_name          object
# dtype: object

# %%
#Corregimos fecha y hora de date_enroll y enroll_end
Itinearios['date_enroll']= pd.to_datetime(Itinearios['date_enroll'],utc=True)
Itinearios['enroll_end']= pd.to_datetime(Itinearios['enroll_end'],utc=True)
Itinearios
# Out:
#      Unnamed: 0  active_flag  category_id               date_enroll  \
# 0             0            0            8 2020-05-03 23:00:00+00:00
# 1             1            1            2 2021-07-21 23:00:00+00:00
# 2             2            1            8 2021-09-07 23:00:00+00:00
# 3             3            0            2 2020-06-17 23:00:00+00:00
# 4             4            0            2 2020-09-23 23:00:00+00:00
# ..          ...          ...          ...                       ...
# 462         462            1            5 2021-10-24 23:00:00+00:00
# 463         463            1            5 2021-10-24 23:00:00+00:00
# 464         464            1            5 2021-10-24 23:00:00+00:00
# 465         465            1            8 2021-10-27 23:00:00+00:00
# 466         466            1            8 2021-10-27 23:00:00+00:00
#
#                    enroll_end  program_id remarks  tutor_academico_id  \
# 0   2023-04-01 22:59:00+00:00          66     NaN                   0
# 1                         NaT         145     NaN                   0
# 2                         NaT         146     NaN                   0
# 3                         NaT          64     NaN                 148
# 4   2021-06-30 22:59:00+00:00         135     NaN                 148
# ..                        ...         ...     ...                 ...
# 462                       NaT         163     NaN                   0
# 463                       NaT         163     NaN                   0
# 464                       NaT         163     NaN                   0
# 465                       NaT          66     NaN                   0
# 466                       NaT         188     NaN                   0
#
#      tutor_empresa_id  user_id     category_name  \
# 0                 190        3  SOPORTE&OPERARIO
# 1                  50        3              DUAL
# 2                 110        3  SOPORTE&OPERARIO
# 3                  41        4              DUAL
# 4                  41        4              DUAL
# ..                ...      ...               ...
# 462               286      433      ESPECIALISTA
# 463               287      434      ESPECIALISTA
# 464               285      435      ESPECIALISTA
# 465               190      436  SOPORTE&OPERARIO
# 466               190      436  SOPORTE&OPERARIO
#
#                               program_name
# 0          Tratamiento Térmico ABP Bergara
# 1                               pruebas_01
# 2               Operario Control Final CBI
# 3                 ITI GRADO DUAL 2019-2020
# 4                 ITI GRADO DUAL 2020-2021
# ..                                     ...
# 462  Maquinista Mecanizados Autogestión MT
# 463  Maquinista Mecanizados Autogestión MT
# 464  Maquinista Mecanizados Autogestión MT
# 465        Tratamiento Térmico ABP Bergara
# 466                 Control Visual Mec ABP
#
# [467 rows x 12 columns]

# %%
#Tipos de variables corregido fecha y hora
Itinearios.dtypes
# Out:
# Unnamed: 0                          int64
# active_flag                         int64
# category_id                         int64
# date_enroll           datetime64[ns, UTC]
# enroll_end            datetime64[ns, UTC]
# program_id                          int64
# remarks                            object
# tutor_academico_id                  int64
# tutor_empresa_id                    int64
# user_id                             int64
# category_name                      object
# program_name                       object
# dtype: object

# %%
#Duplicados
Itinearios.duplicated().sum() # busca duplicados de fila completa
# Out:
# 0

# %%
#NA'S
Itinearios.isna()
Itinearios.isna().sum()
# Out:
# Unnamed: 0              0
# active_flag             0
# category_id             0
# date_enroll             1
# enroll_end            297
# program_id              0
# remarks               464
# tutor_academico_id      0
# tutor_empresa_id        0
# user_id                 0
# category_name           0
# program_name            0
# dtype: int64

# %%
#Eliminamos la columna 'Unnamed: 0' ya que no aporta valor.
#Eliminamos la columna 'remarcks' ya que casi tiene un 100% de NA
#Eliminamos de momento la variable 'enroll_end' ya que tiene mas de un 60% de NA.
Itinearios=Itinearios.drop(['Unnamed: 0'], axis=1)
Itinearios=Itinearios.drop(['remarks'], axis=1)
Itinearios=Itinearios.drop(['enroll_end'], axis=1)

# %%
Itinearios
# Out:
#      active_flag  category_id               date_enroll  program_id  \
# 0              0            8 2020-05-03 23:00:00+00:00          66
# 1              1            2 2021-07-21 23:00:00+00:00         145
# 2              1            8 2021-09-07 23:00:00+00:00         146
# 3              0            2 2020-06-17 23:00:00+00:00          64
# 4              0            2 2020-09-23 23:00:00+00:00         135
# ..           ...          ...                       ...         ...
# 462            1            5 2021-10-24 23:00:00+00:00         163
# 463            1            5 2021-10-24 23:00:00+00:00         163
# 464            1            5 2021-10-24 23:00:00+00:00         163
# 465            1            8 2021-10-27 23:00:00+00:00          66
# 466            1            8 2021-10-27 23:00:00+00:00         188
#
#      tutor_academico_id  tutor_empresa_id  user_id     category_name  \
# 0                     0               190        3  SOPORTE&OPERARIO
# 1                     0                50        3              DUAL
# 2                     0               110        3  SOPORTE&OPERARIO
# 3                   148                41        4              DUAL
# 4                   148                41        4              DUAL
# ..                  ...               ...      ...               ...
# 462                   0               286      433      ESPECIALISTA
# 463                   0               287      434      ESPECIALISTA
# 464                   0               285      435      ESPECIALISTA
# 465                   0               190      436  SOPORTE&OPERARIO
# 466                   0               190      436  SOPORTE&OPERARIO
#
#                               program_name
# 0          Tratamiento Térmico ABP Bergara
# 1                               pruebas_01
# 2               Operario Control Final CBI
# 3                 ITI GRADO DUAL 2019-2020
# 4                 ITI GRADO DUAL 2020-2021
# ..                                     ...
# 462  Maquinista Mecanizados Autogestión MT
# 463  Maquinista Mecanizados Autogestión MT
# 464  Maquinista Mecanizados Autogestión MT
# 465        Tratamiento Térmico ABP Bergara
# 466                 Control Visual Mec ABP
#
# [467 rows x 9 columns]

# %%
Notas_Cursos
# Out:
#       Unnamed: 0  enroll_grade_id  active_flag  course_id  enroll_id  grade  \
# 0              0            17681            1        224        802   0.00
# 1              1            16572            1        224        771   9.32
# 2              2            16590            1        224        774   9.66
# 3              3            16578            1        224        772    NaN
# 4              4            16584            1        224        773    NaN
# ...          ...              ...          ...        ...        ...    ...
# 3893        3893            19558            1        278        838    NaN
# 3894        3894            19568            1        278        839    NaN
# 3895        3895            19578            1        278        840    NaN
# 3896        3896            19913            1        278        850    NaN
# 3897        3897            21551            1        278        885    NaN
#
#       online_progress                           course_name  user_id  \
# 0                 0.0  A - FORMACIÓN ESPECÍFICA CALIDAD ABP      138
# 1                 0.0  A - FORMACIÓN ESPECÍFICA CALIDAD ABP      262
# 2                 0.0  A - FORMACIÓN ESPECÍFICA CALIDAD ABP      265
# 3                 NaN  A - FORMACIÓN ESPECÍFICA CALIDAD ABP      263
# 4                 NaN  A - FORMACIÓN ESPECÍFICA CALIDAD ABP      264
# ...               ...                                   ...      ...
# 3893              NaN                Trazabilidad LPPFe MEC      311
# 3894              NaN                Trazabilidad LPPFe MEC      312
# 3895              NaN                Trazabilidad LPPFe MEC      313
# 3896              NaN                Trazabilidad LPPFe MEC      317
# 3897              NaN                Trazabilidad LPPFe MEC      324
#
#       Unnamed: 8
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 3893         NaN
# 3894         NaN
# 3895         NaN
# 3896         NaN
# 3897         NaN
#
# [3898 rows x 10 columns]

# %%
Notas_Cursos.columns
# Out:
# Index(['Unnamed: 0', 'enroll_grade_id', 'active_flag', 'course_id',
#        'enroll_id', 'grade', 'online_progress', 'course_name', 'user_id',
#        'Unnamed: 8'],
#       dtype='object')

# %%
Notas_Cursos.shape
# Out:
# (3898, 10)

# %%
Notas_Cursos.info
# Out:
# <bound method DataFrame.info of       Unnamed: 0  enroll_grade_id  active_flag  course_id  enroll_id  grade  \
# 0              0            17681            1        224        802   0.00
# 1              1            16572            1        224        771   9.32
# 2              2            16590            1        224        774   9.66
# 3              3            16578            1        224        772    NaN
# 4              4            16584            1        224        773    NaN
# ...          ...              ...          ...        ...        ...    ...
# 3893        3893            19558            1        278        838    NaN
# 3894        3894            19568            1        278        839    NaN
# 3895        3895            19578            1        278        840    NaN
# 3896        3896            19913            1        278        850    NaN
# 3897        3897            21551            1        278        885    NaN
#
#       online_progress                           course_name  user_id  \
# 0                 0.0  A - FORMACIÓN ESPECÍFICA CALIDAD ABP      138
# 1                 0.0  A - FORMACIÓN ESPECÍFICA CALIDAD ABP      262
# 2                 0.0  A - FORMACIÓN ESPECÍFICA CALIDAD ABP      265
# 3                 NaN  A - FORMACIÓN ESPECÍFICA CALIDAD ABP      263
# 4                 NaN  A - FORMACIÓN ESPECÍFICA CALIDAD ABP      264
# ...               ...                                   ...      ...
# 3893              NaN                Trazabilidad LPPFe MEC      311
# 3894              NaN                Trazabilidad LPPFe MEC      312
# 3895              NaN                Trazabilidad LPPFe MEC      313
# 3896              NaN                Trazabilidad LPPFe MEC      317
# 3897              NaN                Trazabilidad LPPFe MEC      324
#
#       Unnamed: 8
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 3893         NaN
# 3894         NaN
# 3895         NaN
# 3896         NaN
# 3897         NaN
#
# [3898 rows x 10 columns]>

# %%
Notas_Cursos.dtypes
# Out:
# Unnamed: 0           int64
# enroll_grade_id      int64
# active_flag          int64
# course_id            int64
# enroll_id            int64
# grade              float64
# online_progress    float64
# course_name         object
# user_id              int64
# Unnamed: 8         float64
# dtype: object

# %%
#Eliminamos la columna 'Unnamed: 0' ya que no aporta valor.
Notas_Cursos=Notas_Cursos.drop(['Unnamed: 0'], axis=1)
Notas_Cursos=Notas_Cursos.drop(['Unnamed: 8'], axis=1)

# %%
#Duplicados
Notas_Cursos.duplicated().sum() #busca duplicados de fila completa
# Out:
# 0

# %%
#NA'S
Notas_Cursos.isna()
Notas_Cursos.isna().sum()
# Out:
# enroll_grade_id       0
# active_flag           0
# course_id             0
# enroll_id             0
# grade              2423
# online_progress    2380
# course_name           0
# user_id               0
# dtype: int64

# %%
#Duplicados
Notas_Cursos.duplicated(subset = ['course_id', 'user_id','online_progress']).sum()
# Out:
# 663

# %%
Notas_Cursos=Notas_Cursos.drop_duplicates(subset = ['course_id', 'user_id','online_progress'])

# %%
Notas_Cursos.isna().sum()
# Out:
# enroll_grade_id       0
# active_flag           0
# course_id             0
# enroll_id             0
# grade              1946
# online_progress    1953
# course_name           0
# user_id               0
# dtype: int64

# %%
Notas_Cursos = Notas_Cursos.fillna(-999)

# %%
Notas_Cursos.dtypes
# Out:
# enroll_grade_id      int64
# active_flag          int64
# course_id            int64
# enroll_id            int64
# grade              float64
# online_progress    float64
# course_name         object
# user_id              int64
# dtype: object

# %%
Notas_Cursos[Notas_Cursos['online_progress']>=-1].grade.plot(kind ="box")
# Out:
# <AxesSubplot:>

# %%
Notas_Cursos.describe()
# Out:
#        enroll_grade_id  active_flag    course_id    enroll_id        grade  \
# count      3235.000000  3235.000000  3235.000000  3235.000000  3235.000000
# mean      20826.524575     0.978671   199.890572   853.059042  -598.592207
# std        5867.881146     0.144502    72.942386   144.606747   492.070586
# min         564.000000     0.000000    10.000000   465.000000  -999.000000
# 25%       18907.500000     1.000000   201.000000   787.500000  -999.000000
# 50%       22566.000000     1.000000   230.000000   907.000000  -999.000000
# 75%       24703.500000     1.000000   240.000000   957.000000     0.000000
# max       27042.000000     1.000000   306.000000  1016.000000   100.000000
#
#        online_progress      user_id
# count      3235.000000  3235.000000
# mean       -590.095929   291.537867
# std         505.578019   126.848377
# min        -999.000000     3.000000
# 25%        -999.000000   191.500000
# 50%        -999.000000   348.000000
# 75%           0.000000   392.000000
# max         100.000000   436.000000

# %%
Roles
# Out:
#    Unnamed: 0  role_id    role_name
# 0           0        1    LBL_ADMIN
# 1           1        2  LBL_MANAGER
# 2           2        3    LBL_TUTOR
# 3           3        4  LBL_STUDENT

# %%
Roles.columns
# Out:
# Index(['Unnamed: 0', 'role_id', 'role_name'], dtype='object')

# %%
Roles.shape
# Out:
# (4, 3)

# %%
Roles.info
# Out:
# <bound method DataFrame.info of    Unnamed: 0  role_id    role_name
# 0           0        1    LBL_ADMIN
# 1           1        2  LBL_MANAGER
# 2           2        3    LBL_TUTOR
# 3           3        4  LBL_STUDENT>

# %%
#Tipo de variables
Roles.dtypes
# Out:
# Unnamed: 0     int64
# role_id        int64
# role_name     object
# dtype: object

# %%
#Duplicados
Roles.duplicated().sum() #busca duplicados de fila completa
# Out:
# 0

# %%
#NA'S
Roles.isna()
Roles.isna().sum()
# Out:
# Unnamed: 0    0
# role_id       0
# role_name     0
# dtype: int64

# %%
#Eliminamos la columna 'Unnamed: 0' ya que no aporta valor.
Roles=Roles.drop(['Unnamed: 0'], axis=1)

# %%
Roles
# Out:
#    role_id    role_name
# 0        1    LBL_ADMIN
# 1        2  LBL_MANAGER
# 2        3    LBL_TUTOR
# 3        4  LBL_STUDENT

# %%
Plantas
# Out:
#     Unnamed: 0  planta_id       planta_name
# 0            0          1       ABP Bergara
# 1            1          2      ABP Arrasate
# 2            2          3       ABP Kunshan
# 3            3          4        ABP México
# 4            4          5   MT Aretxabaleta
# 5            5          6     MT Eslovaquia
# 6            6          7               SAT
# 7            7          8    LPP Eskoriatza
# 8            8          9      LPD Arrasate
# 9            9         10       LPC Usurbil
# 10          10         11           Tafalla
# 11          11         12        GISEDERLAN
# 12          12         13            BRASIL
# 13          13         14           EDERTEK
# 14          14         15  BULEGO OROKORRAK
# 15          15         16      Fagorederlan
# 16          16         17            PLANTA
# 17          17         18      MT Aretxabal

# %%
Plantas=Plantas.drop(['Unnamed: 0'], axis=1)

# %%
Plantas.dtypes
# Out:
# planta_id       int64
# planta_name    object
# dtype: object

# %%
#Duplicados
Plantas.duplicated().sum() # busca duplicados de fila completa
# Out:
# 0

# %%
#NA'S
Plantas.isna().sum()
# Out:
# planta_id      0
# planta_name    0
# dtype: int64

# %%
Plantas
# Out:
#     planta_id       planta_name
# 0           1       ABP Bergara
# 1           2      ABP Arrasate
# 2           3       ABP Kunshan
# 3           4        ABP México
# 4           5   MT Aretxabaleta
# 5           6     MT Eslovaquia
# 6           7               SAT
# 7           8    LPP Eskoriatza
# 8           9      LPD Arrasate
# 9          10       LPC Usurbil
# 10         11           Tafalla
# 11         12        GISEDERLAN
# 12         13            BRASIL
# 13         14           EDERTEK
# 14         15  BULEGO OROKORRAK
# 15         16      Fagorederlan
# 16         17            PLANTA
# 17         18      MT Aretxabal

# %%
Accesos
# Out:
#       Unnamed: 0       description                  timestamp  mdl_user_id  \
# 0              0   LOGIN AS SRM OK  2021-09-14T13:26:51+01:00            3
# 1              1   LOGIN AS SRM OK  2021-10-13T10:54:42+01:00            3
# 2              2   LOGIN AS SRM OK  2021-10-13T11:53:33+01:00            3
# 3              3   LOGIN AS SRM OK  2021-10-14T14:28:42+01:00            3
# 4              4   LOGIN AS SRM OK  2021-10-14T14:30:07+01:00            3
# ...          ...               ...                        ...          ...
# 8811        8811  LOGOUT AS SRM OK       2020-11-15T19:06:36Z            3
# 8812        8812  LOGOUT AS SRM OK       2020-11-15T19:12:58Z            3
# 8813        8813  LOGOUT AS SRM OK       2020-11-15T19:39:17Z            3
# 8814        8814  LOGOUT AS SRM OK  2021-10-13T10:39:17+01:00            3
# 8815        8815  LOGOUT AS SRM OK  2021-10-13T11:35:21+01:00            3
#
#       user_id
# 0         134
# 1         134
# 2         134
# 3         134
# 4         134
# ...       ...
# 8811      134
# 8812      134
# 8813      134
# 8814      134
# 8815      134
#
# [8816 rows x 5 columns]

# %%
Accesos=Accesos.drop(['Unnamed: 0'], axis=1)

# %%
Accesos.dtypes
# Out:
# description    object
# timestamp      object
# mdl_user_id     int64
# user_id         int64
# dtype: object

# %%
Accesos['timestamp']= pd.to_datetime(Accesos['timestamp'],utc=True)

# %%
Accesos
# Out:
#            description                 timestamp  mdl_user_id  user_id
# 0      LOGIN AS SRM OK 2021-09-14 12:26:51+00:00            3      134
# 1      LOGIN AS SRM OK 2021-10-13 09:54:42+00:00            3      134
# 2      LOGIN AS SRM OK 2021-10-13 10:53:33+00:00            3      134
# 3      LOGIN AS SRM OK 2021-10-14 13:28:42+00:00            3      134
# 4      LOGIN AS SRM OK 2021-10-14 13:30:07+00:00            3      134
# ...                ...                       ...          ...      ...
# 8811  LOGOUT AS SRM OK 2020-11-15 19:06:36+00:00            3      134
# 8812  LOGOUT AS SRM OK 2020-11-15 19:12:58+00:00            3      134
# 8813  LOGOUT AS SRM OK 2020-11-15 19:39:17+00:00            3      134
# 8814  LOGOUT AS SRM OK 2021-10-13 09:39:17+00:00            3      134
# 8815  LOGOUT AS SRM OK 2021-10-13 10:35:21+00:00            3      134
#
# [8816 rows x 4 columns]

# %%
Accesos.dtypes
# Out:
# description                 object
# timestamp      datetime64[ns, UTC]
# mdl_user_id                  int64
# user_id                      int64
# dtype: object

# %%
#Duplicados
Accesos.duplicated().sum() # busca duplicados de fila completa
# Out:
# 26

# %%
Accesos=Accesos.drop_duplicates()

# %%
Accesos.duplicated().sum()
# Out:
# 0

# %%
Accesos.isna().sum()
# Out:
# description    0
# timestamp      0
# mdl_user_id    0
# user_id        0
# dtype: int64

# %%
Accesos.describe()
# Out:
#        mdl_user_id      user_id
# count  8790.000000  8790.000000
# mean    108.729465   142.867577
# std     108.199826    64.462490
# min       3.000000     3.000000
# 25%      11.000000   134.000000
# 50%      41.000000   135.000000
# 75%     190.000000   145.000000
# max     461.000000   436.000000

# %%
Acceso_1ero_ultimo
# Out:
#      Unnamed: 0  mdl_user_id                                1er acceso  \
# 0             0            3   jueves, 20 de septiembre de 2018, 12:19
# 1             1           10  viernes, 28 de septiembre de 2018, 12:49
# 2             2           11   sábado, 29 de septiembre de 2018, 18:35
# 3             3           13       martes, 2 de octubre de 2018, 09:46
# 4             4           14       martes, 2 de octubre de 2018, 18:42
# ..          ...          ...                                       ...
# 367         367          457                                        --
# 368         368          458                                        --
# 369         369          459                                        --
# 370         370          460                                        --
# 371         371          461      jueves, 28 de octubre de 2021, 15:43
#
#                              ultimo acceso
# 0    viernes, 29 de octubre de 2021, 15:42
# 1    miércoles, 14 de julio de 2021, 16:28
# 2      martes, 5 de octubre de 2021, 10:12
# 3       jueves, 5 de agosto de 2021, 12:34
# 4        lunes, 19 de julio de 2021, 12:37
# ..                                     ...
# 367                                     --
# 368                                     --
# 369                                     --
# 370                                     --
# 371   jueves, 28 de octubre de 2021, 16:03
#
# [372 rows x 4 columns]

# %%
Acceso_1ero_ultimo.dtypes
# Out:
# Unnamed: 0        int64
# mdl_user_id       int64
# 1er acceso       object
# ultimo acceso    object
# dtype: object

# %%
Acceso_1ero_ultimo=Acceso_1ero_ultimo.drop(['Unnamed: 0'], axis=1)

# %%
#Duplicados
Acceso_1ero_ultimo.duplicated().sum() # busca duplicados de fila completa
# Out:
# 0

# %%
Acceso_1ero_ultimo['1er acceso'][Acceso_1ero_ultimo['1er acceso']=="--"]=None
Acceso_1ero_ultimo['ultimo acceso'][Acceso_1ero_ultimo['ultimo acceso']=="--"]=None
# Out:
# <ipython-input-117-7c59f6b7e52e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Acceso_1ero_ultimo['1er acceso'][Acceso_1ero_ultimo['1er acceso']=="--"]=None
# <ipython-input-117-7c59f6b7e52e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Acceso_1ero_ultimo['ultimo acceso'][Acceso_1ero_ultimo['ultimo acceso']=="--"]=None

# %%
Acceso_1ero_ultimo
# Out:
#      mdl_user_id                                1er acceso  \
# 0              3   jueves, 20 de septiembre de 2018, 12:19
# 1             10  viernes, 28 de septiembre de 2018, 12:49
# 2             11   sábado, 29 de septiembre de 2018, 18:35
# 3             13       martes, 2 de octubre de 2018, 09:46
# 4             14       martes, 2 de octubre de 2018, 18:42
# ..           ...                                       ...
# 367          457                                      None
# 368          458                                      None
# 369          459                                      None
# 370          460                                      None
# 371          461      jueves, 28 de octubre de 2021, 15:43
#
#                              ultimo acceso
# 0    viernes, 29 de octubre de 2021, 15:42
# 1    miércoles, 14 de julio de 2021, 16:28
# 2      martes, 5 de octubre de 2021, 10:12
# 3       jueves, 5 de agosto de 2021, 12:34
# 4        lunes, 19 de julio de 2021, 12:37
# ..                                     ...
# 367                                   None
# 368                                   None
# 369                                   None
# 370                                   None
# 371   jueves, 28 de octubre de 2021, 16:03
#
# [372 rows x 3 columns]

# %%
Acceso_1ero_ultimo.isna().sum()
# Out:
# mdl_user_id       0
# 1er acceso       77
# ultimo acceso    76
# dtype: int64

# %%
Acceso_1ero_ultimo.duplicated(subset = ['1er acceso', 'ultimo acceso']).sum()
# Out:
# 76

# %%
Acceso_1ero_ultimo[Acceso_1ero_ultimo.duplicated(subset = ['1er acceso', 'ultimo acceso'])].fillna('NUNCA')
# Out:
#      mdl_user_id                          1er acceso  \
# 47            64                               NUNCA
# 48            65                               NUNCA
# 56            76                               NUNCA
# 62            84                               NUNCA
# 75            99  jueves, 27 de junio de 2019, 20:13
# ..           ...                                 ...
# 366          456                               NUNCA
# 367          457                               NUNCA
# 368          458                               NUNCA
# 369          459                               NUNCA
# 370          460                               NUNCA
#
#                           ultimo acceso
# 47                                NUNCA
# 48                                NUNCA
# 56                                NUNCA
# 62                                NUNCA
# 75   jueves, 27 de junio de 2019, 20:13
# ..                                  ...
# 366                               NUNCA
# 367                               NUNCA
# 368                               NUNCA
# 369                               NUNCA
# 370                               NUNCA
#
# [76 rows x 3 columns]

# %%
Acceso_1ero_ultimo[Acceso_1ero_ultimo.duplicated(subset = ['1er acceso', 'ultimo acceso'])]=Acceso_1ero_ultimo[Acceso_1ero_ultimo.duplicated(subset = ['1er acceso', 'ultimo acceso'])].fillna('NUNCA')

# %%
Acceso_1ero_ultimo.isna().sum()
# Out:
# mdl_user_id      0
# 1er acceso       2
# ultimo acceso    1
# dtype: int64

# %%
Acceso_1ero_ultimo[Acceso_1ero_ultimo['1er acceso'].isna()]
# Out:
#      mdl_user_id 1er acceso                       ultimo acceso
# 46            63       None                                None
# 132          165       None  martes, 29 de junio de 2021, 12:55

# %%
Acceso_1ero_ultimo[Acceso_1ero_ultimo['1er acceso'].isna()]='NUNCA'

# %%
Acceso_1ero_ultimo.isna().sum()
# Out:
# mdl_user_id      0
# 1er acceso       0
# ultimo acceso    0
# dtype: int64

# %%
Acceso_1ero_ultimo
# Out:
#     mdl_user_id                                1er acceso  \
# 0             3   jueves, 20 de septiembre de 2018, 12:19
# 1            10  viernes, 28 de septiembre de 2018, 12:49
# 2            11   sábado, 29 de septiembre de 2018, 18:35
# 3            13       martes, 2 de octubre de 2018, 09:46
# 4            14       martes, 2 de octubre de 2018, 18:42
# ..          ...                                       ...
# 367         457                                     NUNCA
# 368         458                                     NUNCA
# 369         459                                     NUNCA
# 370         460                                     NUNCA
# 371         461      jueves, 28 de octubre de 2021, 15:43
#
#                              ultimo acceso
# 0    viernes, 29 de octubre de 2021, 15:42
# 1    miércoles, 14 de julio de 2021, 16:28
# 2      martes, 5 de octubre de 2021, 10:12
# 3       jueves, 5 de agosto de 2021, 12:34
# 4        lunes, 19 de julio de 2021, 12:37
# ..                                     ...
# 367                                  NUNCA
# 368                                  NUNCA
# 369                                  NUNCA
# 370                                  NUNCA
# 371   jueves, 28 de octubre de 2021, 16:03
#
# [372 rows x 3 columns]

# %%
Actividades
# Out:
#       Unnamed: 0  mdl_user_id                           course_name  \
# 0              0          190  A - FORMACIÓN ESPECÍFICA CALIDAD ABP
# 1              1          190  A - FORMACIÓN ESPECÍFICA CALIDAD ABP
# 2              2          296  A - FORMACIÓN ESPECÍFICA CALIDAD ABP
# 3              3          296  A - FORMACIÓN ESPECÍFICA CALIDAD ABP
# 4              4          299  A - FORMACIÓN ESPECÍFICA CALIDAD ABP
# ...          ...          ...                                   ...
# 3459        3459           21                Trazabilidad LPPFe MEC
# 3460        3460           21                Trazabilidad LPPFe MEC
# 3461        3461           21                Trazabilidad LPPFe MEC
# 3462        3462          339                Trazabilidad LPPFe MEC
# 3463        3463          339                Trazabilidad LPPFe MEC
#
#       course_id                     category  \
# 0           224    TÉCNICOS/TECNOLÓGICOS ABP
# 1           224    TÉCNICOS/TECNOLÓGICOS ABP
# 2           224    TÉCNICOS/TECNOLÓGICOS ABP
# 3           224    TÉCNICOS/TECNOLÓGICOS ABP
# 4           224    TÉCNICOS/TECNOLÓGICOS ABP
# ...         ...                          ...
# 3459        278  Técnico / Tecnológico LPPFE
# 3460        278  Técnico / Tecnológico LPPFE
# 3461        278  Técnico / Tecnológico LPPFE
# 3462        278  Técnico / Tecnológico LPPFE
# 3463        278  Técnico / Tecnológico LPPFE
#
#                                          actividad_name  grade  \
# 0                                            TEST FINAL    NaN
# 1          A - FORMACIÓN ESPECÍFICA CALIDAD ABP - Total    NaN
# 2          A - FORMACIÓN ESPECÍFICA CALIDAD ABP - Total   9.32
# 3                                            TEST FINAL   9.32
# 4                                            TEST FINAL   9.66
# ...                                                 ...    ...
# 3459  TEST - Enbalajearen etiketa / Etiquetado de em...   9.29
# 3460                     Trazabilidad LPPFe MEC - Total   9.29
# 3461                     Trazabilidad LPPFe MEC - Total   9.29
# 3462                     Trazabilidad LPPFe MEC - Total  10.00
# 3463  TEST - Enbalajearen etiketa / Etiquetado de em...  10.00
#
#                      time
# 0                     NaN
# 1                     NaN
# 2     2020-12-18 15:25:05
# 3     2020-12-18 15:25:05
# 4     2020-12-18 16:45:34
# ...                   ...
# 3459  2021-06-14 16:36:31
# 3460  2021-06-14 16:36:32
# 3461  2021-06-14 16:36:32
# 3462  2021-06-14 10:13:15
# 3463  2021-06-14 10:13:15
#
# [3464 rows x 8 columns]

# %%
Actividades=Actividades.drop(['Unnamed: 0'], axis=1)

# %%
Actividades
# Out:
#       mdl_user_id                           course_name  course_id  \
# 0             190  A - FORMACIÓN ESPECÍFICA CALIDAD ABP        224
# 1             190  A - FORMACIÓN ESPECÍFICA CALIDAD ABP        224
# 2             296  A - FORMACIÓN ESPECÍFICA CALIDAD ABP        224
# 3             296  A - FORMACIÓN ESPECÍFICA CALIDAD ABP        224
# 4             299  A - FORMACIÓN ESPECÍFICA CALIDAD ABP        224
# ...           ...                                   ...        ...
# 3459           21                Trazabilidad LPPFe MEC        278
# 3460           21                Trazabilidad LPPFe MEC        278
# 3461           21                Trazabilidad LPPFe MEC        278
# 3462          339                Trazabilidad LPPFe MEC        278
# 3463          339                Trazabilidad LPPFe MEC        278
#
#                          category  \
# 0       TÉCNICOS/TECNOLÓGICOS ABP
# 1       TÉCNICOS/TECNOLÓGICOS ABP
# 2       TÉCNICOS/TECNOLÓGICOS ABP
# 3       TÉCNICOS/TECNOLÓGICOS ABP
# 4       TÉCNICOS/TECNOLÓGICOS ABP
# ...                           ...
# 3459  Técnico / Tecnológico LPPFE
# 3460  Técnico / Tecnológico LPPFE
# 3461  Técnico / Tecnológico LPPFE
# 3462  Técnico / Tecnológico LPPFE
# 3463  Técnico / Tecnológico LPPFE
#
#                                          actividad_name  grade  \
# 0                                            TEST FINAL    NaN
# 1          A - FORMACIÓN ESPECÍFICA CALIDAD ABP - Total    NaN
# 2          A - FORMACIÓN ESPECÍFICA CALIDAD ABP - Total   9.32
# 3                                            TEST FINAL   9.32
# 4                                            TEST FINAL   9.66
# ...                                                 ...    ...
# 3459  TEST - Enbalajearen etiketa / Etiquetado de em...   9.29
# 3460                     Trazabilidad LPPFe MEC - Total   9.29
# 3461                     Trazabilidad LPPFe MEC - Total   9.29
# 3462                     Trazabilidad LPPFe MEC - Total  10.00
# 3463  TEST - Enbalajearen etiketa / Etiquetado de em...  10.00
#
#                      time
# 0                     NaN
# 1                     NaN
# 2     2020-12-18 15:25:05
# 3     2020-12-18 15:25:05
# 4     2020-12-18 16:45:34
# ...                   ...
# 3459  2021-06-14 16:36:31
# 3460  2021-06-14 16:36:32
# 3461  2021-06-14 16:36:32
# 3462  2021-06-14 10:13:15
# 3463  2021-06-14 10:13:15
#
# [3464 rows x 7 columns]

# %%
Actividades.dtypes
# Out:
# mdl_user_id         int64
# course_name        object
# course_id           int64
# category           object
# actividad_name     object
# grade             float64
# time               object
# dtype: object

# %%
Actividades['time']= pd.to_datetime(Actividades['time'])

# %%
Actividades.dtypes
# Out:
# mdl_user_id                int64
# course_name               object
# course_id                  int64
# category                  object
# actividad_name            object
# grade                    float64
# time              datetime64[ns]
# dtype: object

# %%
#Duplicados
Actividades.duplicated().sum() # busca duplicados de fila completa
# Out:
# 89

# %%
Actividades=Actividades.drop_duplicates()

# %%
Actividades.duplicated().sum()
# Out:
# 0

# %%
Actividades.isna().sum()
# Out:
# mdl_user_id          0
# course_name          0
# course_id            0
# category             0
# actividad_name       4
# grade             1278
# time              1263
# dtype: int64

# %%
Actividades=Actividades[Actividades['actividad_name'].notna()]

# %%
Actividades.isna().sum()
# Out:
# mdl_user_id          0
# course_name          0
# course_id            0
# category             0
# actividad_name       0
# grade             1274
# time              1259
# dtype: int64

# %%
Actividades['grade']=Actividades['grade'].fillna('-999')

# %%
Actividades.isna().sum()
# Out:
# mdl_user_id          0
# course_name          0
# course_id            0
# category             0
# actividad_name       0
# grade                0
# time              1259
# dtype: int64

# %%
Actividades.time=Actividades.time.fillna('1999-01-01 00:00:00')

# %%
Actividades
# Out:
#       mdl_user_id                           course_name  course_id  \
# 0             190  A - FORMACIÓN ESPECÍFICA CALIDAD ABP        224
# 1             190  A - FORMACIÓN ESPECÍFICA CALIDAD ABP        224
# 2             296  A - FORMACIÓN ESPECÍFICA CALIDAD ABP        224
# 3             296  A - FORMACIÓN ESPECÍFICA CALIDAD ABP        224
# 4             299  A - FORMACIÓN ESPECÍFICA CALIDAD ABP        224
# ...           ...                                   ...        ...
# 3457          190                Trazabilidad LPPFe MEC        278
# 3458           21                Trazabilidad LPPFe MEC        278
# 3460           21                Trazabilidad LPPFe MEC        278
# 3462          339                Trazabilidad LPPFe MEC        278
# 3463          339                Trazabilidad LPPFe MEC        278
#
#                          category  \
# 0       TÉCNICOS/TECNOLÓGICOS ABP
# 1       TÉCNICOS/TECNOLÓGICOS ABP
# 2       TÉCNICOS/TECNOLÓGICOS ABP
# 3       TÉCNICOS/TECNOLÓGICOS ABP
# 4       TÉCNICOS/TECNOLÓGICOS ABP
# ...                           ...
# 3457  Técnico / Tecnológico LPPFE
# 3458  Técnico / Tecnológico LPPFE
# 3460  Técnico / Tecnológico LPPFE
# 3462  Técnico / Tecnológico LPPFE
# 3463  Técnico / Tecnológico LPPFE
#
#                                          actividad_name grade  \
# 0                                            TEST FINAL  -999
# 1          A - FORMACIÓN ESPECÍFICA CALIDAD ABP - Total  -999
# 2          A - FORMACIÓN ESPECÍFICA CALIDAD ABP - Total  9.32
# 3                                            TEST FINAL  9.32
# 4                                            TEST FINAL  9.66
# ...                                                 ...   ...
# 3457                     Trazabilidad LPPFe MEC - Total  -999
# 3458  TEST - Enbalajearen etiketa / Etiquetado de em...  9.29
# 3460                     Trazabilidad LPPFe MEC - Total  9.29
# 3462                     Trazabilidad LPPFe MEC - Total  10.0
# 3463  TEST - Enbalajearen etiketa / Etiquetado de em...  10.0
#
#                      time
# 0     1999-01-01 00:00:00
# 1     1999-01-01 00:00:00
# 2     2020-12-18 15:25:05
# 3     2020-12-18 15:25:05
# 4     2020-12-18 16:45:34
# ...                   ...
# 3457  1999-01-01 00:00:00
# 3458  2021-06-14 16:36:31
# 3460  2021-06-14 16:36:32
# 3462  2021-06-14 10:13:15
# 3463  2021-06-14 10:13:15
#
# [3371 rows x 7 columns]

# %%
Actividades.isna().sum()
# Out:
# mdl_user_id       0
# course_name       0
# course_id         0
# category          0
# actividad_name    0
# grade             0
# time              0
# dtype: int64

# %%
Actividades.dtypes
# Out:
# mdl_user_id        int64
# course_name       object
# course_id          int64
# category          object
# actividad_name    object
# grade             object
# time              object
# dtype: object

# %%
Actividades['grade']=Actividades['grade'].astype('float')

# %%
Actividades.time=pd.to_datetime(Actividades['time'])

# %%
Actividades[["grade"]].describe()
# Out:
#              grade
# count  3371.000000
# mean   -371.613631
# std     489.093912
# min    -999.000000
# 25%    -999.000000
# 50%       8.330000
# 75%      10.000000
# max      38.850000

# %%
Actividades
# Out:
#       mdl_user_id                           course_name  course_id  \
# 0             190  A - FORMACIÓN ESPECÍFICA CALIDAD ABP        224
# 1             190  A - FORMACIÓN ESPECÍFICA CALIDAD ABP        224
# 2             296  A - FORMACIÓN ESPECÍFICA CALIDAD ABP        224
# 3             296  A - FORMACIÓN ESPECÍFICA CALIDAD ABP        224
# 4             299  A - FORMACIÓN ESPECÍFICA CALIDAD ABP        224
# ...           ...                                   ...        ...
# 3457          190                Trazabilidad LPPFe MEC        278
# 3458           21                Trazabilidad LPPFe MEC        278
# 3460           21                Trazabilidad LPPFe MEC        278
# 3462          339                Trazabilidad LPPFe MEC        278
# 3463          339                Trazabilidad LPPFe MEC        278
#
#                          category  \
# 0       TÉCNICOS/TECNOLÓGICOS ABP
# 1       TÉCNICOS/TECNOLÓGICOS ABP
# 2       TÉCNICOS/TECNOLÓGICOS ABP
# 3       TÉCNICOS/TECNOLÓGICOS ABP
# 4       TÉCNICOS/TECNOLÓGICOS ABP
# ...                           ...
# 3457  Técnico / Tecnológico LPPFE
# 3458  Técnico / Tecnológico LPPFE
# 3460  Técnico / Tecnológico LPPFE
# 3462  Técnico / Tecnológico LPPFE
# 3463  Técnico / Tecnológico LPPFE
#
#                                          actividad_name   grade  \
# 0                                            TEST FINAL -999.00
# 1          A - FORMACIÓN ESPECÍFICA CALIDAD ABP - Total -999.00
# 2          A - FORMACIÓN ESPECÍFICA CALIDAD ABP - Total    9.32
# 3                                            TEST FINAL    9.32
# 4                                            TEST FINAL    9.66
# ...                                                 ...     ...
# 3457                     Trazabilidad LPPFe MEC - Total -999.00
# 3458  TEST - Enbalajearen etiketa / Etiquetado de em...    9.29
# 3460                     Trazabilidad LPPFe MEC - Total    9.29
# 3462                     Trazabilidad LPPFe MEC - Total   10.00
# 3463  TEST - Enbalajearen etiketa / Etiquetado de em...   10.00
#
#                     time
# 0    1999-01-01 00:00:00
# 1    1999-01-01 00:00:00
# 2    2020-12-18 15:25:05
# 3    2020-12-18 15:25:05
# 4    2020-12-18 16:45:34
# ...                  ...
# 3457 1999-01-01 00:00:00
# 3458 2021-06-14 16:36:31
# 3460 2021-06-14 16:36:32
# 3462 2021-06-14 10:13:15
# 3463 2021-06-14 10:13:15
#
# [3371 rows x 7 columns]

# %%
Actividades[Actividades['grade']>=-1].grade.plot(kind ="box")
# Out:
# <AxesSubplot:>

# %%
Actividades=Actividades[Actividades['grade']<=10]

# %%
Actividades[["grade"]].describe()
# Out:
#              grade
# count  3301.000000
# mean   -380.034968
# std     490.784768
# min    -999.000000
# 25%    -999.000000
# 50%       8.330000
# 75%      10.000000
# max      10.000000

# %%
Actividades_10=Actividades[Actividades['grade']>0]

# %%
Actividades_10.grade.plot(kind ="box")
# Out:
# <AxesSubplot:>

# %%
Actividades_10
# Out:
#       mdl_user_id                           course_name  course_id  \
# 2             296  A - FORMACIÓN ESPECÍFICA CALIDAD ABP        224
# 3             296  A - FORMACIÓN ESPECÍFICA CALIDAD ABP        224
# 4             299  A - FORMACIÓN ESPECÍFICA CALIDAD ABP        224
# 5             299  A - FORMACIÓN ESPECÍFICA CALIDAD ABP        224
# 6             296           A - INTRODUCCIÓN MECANIZADO        223
# ...           ...                                   ...        ...
# 3455          370          TRATAMIENTO TÉRMICO ABP B_N3        193
# 3458           21                Trazabilidad LPPFe MEC        278
# 3460           21                Trazabilidad LPPFe MEC        278
# 3462          339                Trazabilidad LPPFe MEC        278
# 3463          339                Trazabilidad LPPFe MEC        278
#
#                          category  \
# 2       TÉCNICOS/TECNOLÓGICOS ABP
# 3       TÉCNICOS/TECNOLÓGICOS ABP
# 4       TÉCNICOS/TECNOLÓGICOS ABP
# 5       TÉCNICOS/TECNOLÓGICOS ABP
# 6       TÉCNICOS/TECNOLÓGICOS ABP
# ...                           ...
# 3455    TÉCNICOS/TECNOLÓGICOS ABP
# 3458  Técnico / Tecnológico LPPFE
# 3460  Técnico / Tecnológico LPPFE
# 3462  Técnico / Tecnológico LPPFE
# 3463  Técnico / Tecnológico LPPFE
#
#                                          actividad_name  grade  \
# 2          A - FORMACIÓN ESPECÍFICA CALIDAD ABP - Total   9.32
# 3                                            TEST FINAL   9.32
# 4                                            TEST FINAL   9.66
# 5          A - FORMACIÓN ESPECÍFICA CALIDAD ABP - Total   9.66
# 6                                                  TEST   8.85
# ...                                                 ...    ...
# 3455               TRATAMIENTO TÉRMICO ABP B_N3 - Total   9.88
# 3458  TEST - Enbalajearen etiketa / Etiquetado de em...   9.29
# 3460                     Trazabilidad LPPFe MEC - Total   9.29
# 3462                     Trazabilidad LPPFe MEC - Total  10.00
# 3463  TEST - Enbalajearen etiketa / Etiquetado de em...  10.00
#
#                     time
# 2    2020-12-18 15:25:05
# 3    2020-12-18 15:25:05
# 4    2020-12-18 16:45:34
# 5    2020-12-18 16:45:34
# 6    2020-12-18 14:54:05
# ...                  ...
# 3455 2021-10-14 23:55:13
# 3458 2021-06-14 16:36:31
# 3460 2021-06-14 16:36:32
# 3462 2021-06-14 10:13:15
# 3463 2021-06-14 10:13:15
#
# [2014 rows x 7 columns]

# %%
Actividades_10
# Out:
#       mdl_user_id                           course_name  course_id  \
# 2             296  A - FORMACIÓN ESPECÍFICA CALIDAD ABP        224
# 3             296  A - FORMACIÓN ESPECÍFICA CALIDAD ABP        224
# 4             299  A - FORMACIÓN ESPECÍFICA CALIDAD ABP        224
# 5             299  A - FORMACIÓN ESPECÍFICA CALIDAD ABP        224
# 6             296           A - INTRODUCCIÓN MECANIZADO        223
# ...           ...                                   ...        ...
# 3455          370          TRATAMIENTO TÉRMICO ABP B_N3        193
# 3458           21                Trazabilidad LPPFe MEC        278
# 3460           21                Trazabilidad LPPFe MEC        278
# 3462          339                Trazabilidad LPPFe MEC        278
# 3463          339                Trazabilidad LPPFe MEC        278
#
#                          category  \
# 2       TÉCNICOS/TECNOLÓGICOS ABP
# 3       TÉCNICOS/TECNOLÓGICOS ABP
# 4       TÉCNICOS/TECNOLÓGICOS ABP
# 5       TÉCNICOS/TECNOLÓGICOS ABP
# 6       TÉCNICOS/TECNOLÓGICOS ABP
# ...                           ...
# 3455    TÉCNICOS/TECNOLÓGICOS ABP
# 3458  Técnico / Tecnológico LPPFE
# 3460  Técnico / Tecnológico LPPFE
# 3462  Técnico / Tecnológico LPPFE
# 3463  Técnico / Tecnológico LPPFE
#
#                                          actividad_name  grade  \
# 2          A - FORMACIÓN ESPECÍFICA CALIDAD ABP - Total   9.32
# 3                                            TEST FINAL   9.32
# 4                                            TEST FINAL   9.66
# 5          A - FORMACIÓN ESPECÍFICA CALIDAD ABP - Total   9.66
# 6                                                  TEST   8.85
# ...                                                 ...    ...
# 3455               TRATAMIENTO TÉRMICO ABP B_N3 - Total   9.88
# 3458  TEST - Enbalajearen etiketa / Etiquetado de em...   9.29
# 3460                     Trazabilidad LPPFe MEC - Total   9.29
# 3462                     Trazabilidad LPPFe MEC - Total  10.00
# 3463  TEST - Enbalajearen etiketa / Etiquetado de em...  10.00
#
#                     time
# 2    2020-12-18 15:25:05
# 3    2020-12-18 15:25:05
# 4    2020-12-18 16:45:34
# 5    2020-12-18 16:45:34
# 6    2020-12-18 14:54:05
# ...                  ...
# 3455 2021-10-14 23:55:13
# 3458 2021-06-14 16:36:31
# 3460 2021-06-14 16:36:32
# 3462 2021-06-14 10:13:15
# 3463 2021-06-14 10:13:15
#
# [2014 rows x 7 columns]

# %%
Actividades.dtypes
# Out:
# mdl_user_id                int64
# course_name               object
# course_id                  int64
# category                  object
# actividad_name            object
# grade                    float64
# time              datetime64[ns]
# dtype: object

# %% [markdown]
# En grades las notas -999 son missings, y en time 1999 son missings

# %%
a=pd.merge(Usuarios.copy(),Tutores_perfil.copy())

# %%
a
# Out:
#      user_id useranonimo_name  active_flag language  last_access  mdl_user_id  \
# 0          3      username_03            1       es          NaN         13.0
# 1          4      username_04            1       es          NaN         14.0
# 2         10      username_10            1       es          NaN         21.0
# 3         10      username_10            1       es          NaN         21.0
# 4         10      username_10            1       es          NaN         21.0
# ..       ...              ...          ...      ...          ...          ...
# 172      369     username_369            1       es          NaN        393.0
# 173      379     username_379            1       es          NaN        444.0
# 174      415     username_415            1       es          NaN        446.0
# 175      423     username_423            1       es          NaN        448.0
# 176      436     username_436            1       es          NaN        461.0
#
#      role_admin  role_manager  role_student  role_tutor      planta_name  \
# 0             0             0             1           0      ABP Bergara
# 1             0             0             1           0     Fagorederlan
# 2             0             0             1           1   LPP Eskoriatza
# 3             0             0             1           1   LPP Eskoriatza
# 4             0             0             1           1   LPP Eskoriatza
# ..          ...           ...           ...         ...              ...
# 172           0             0             1           0  MT Aretxabaleta
# 173           0             0             1           0  MT Aretxabaleta
# 174           0             0             1           0  MT Aretxabaleta
# 175           0             0             1           0  MT Aretxabaleta
# 176           0             1             1           1      ABP Bergara
#
#      Unnamed: 11  perfil_id        perfil_name
# 0            NaN          0    Tutores basicos
# 1            NaN          0    Tutores basicos
# 2            NaN          3  Gestor de empresa
# 3            NaN          6      Tutor empresa
# 4            NaN          0    Tutores basicos
# ..           ...        ...                ...
# 172          NaN          0    Tutores basicos
# 173          NaN          0    Tutores basicos
# 174          NaN          0    Tutores basicos
# 175          NaN          0    Tutores basicos
# 176          NaN          6      Tutor empresa
#
# [177 rows x 14 columns]

# %%
b=pd.merge(a.drop(['active_flag'], axis=1),Itinearios,on='user_id',copy=False)

# %%
b
# Out:
#      user_id useranonimo_name language  last_access  mdl_user_id  role_admin  \
# 0          3      username_03       es          NaN         13.0           0
# 1          3      username_03       es          NaN         13.0           0
# 2          3      username_03       es          NaN         13.0           0
# 3          4      username_04       es          NaN         14.0           0
# 4          4      username_04       es          NaN         14.0           0
# ..       ...              ...      ...          ...          ...         ...
# 397      415     username_415       es          NaN        446.0           0
# 398      415     username_415       es          NaN        446.0           0
# 399      423     username_423       es          NaN        448.0           0
# 400      436     username_436       es          NaN        461.0           0
# 401      436     username_436       es          NaN        461.0           0
#
#      role_manager  role_student  role_tutor      planta_name  Unnamed: 11  \
# 0               0             1           0      ABP Bergara          NaN
# 1               0             1           0      ABP Bergara          NaN
# 2               0             1           0      ABP Bergara          NaN
# 3               0             1           0     Fagorederlan          NaN
# 4               0             1           0     Fagorederlan          NaN
# ..            ...           ...         ...              ...          ...
# 397             0             1           0  MT Aretxabaleta          NaN
# 398             0             1           0  MT Aretxabaleta          NaN
# 399             0             1           0  MT Aretxabaleta          NaN
# 400             1             1           1      ABP Bergara          NaN
# 401             1             1           1      ABP Bergara          NaN
#
#      perfil_id      perfil_name  active_flag  category_id  \
# 0            0  Tutores basicos            0            8
# 1            0  Tutores basicos            1            2
# 2            0  Tutores basicos            1            8
# 3            0  Tutores basicos            0            2
# 4            0  Tutores basicos            0            2
# ..         ...              ...          ...          ...
# 397          0  Tutores basicos            0            5
# 398          0  Tutores basicos            1            5
# 399          0  Tutores basicos            1            5
# 400          6    Tutor empresa            1            8
# 401          6    Tutor empresa            1            8
#
#                   date_enroll  program_id  tutor_academico_id  \
# 0   2020-05-03 23:00:00+00:00          66                   0
# 1   2021-07-21 23:00:00+00:00         145                   0
# 2   2021-09-07 23:00:00+00:00         146                   0
# 3   2020-06-17 23:00:00+00:00          64                 148
# 4   2020-09-23 23:00:00+00:00         135                 148
# ..                        ...         ...                 ...
# 397 2021-10-12 23:00:00+00:00         163                   0
# 398 2021-10-12 23:00:00+00:00         163                   0
# 399 2021-10-12 23:00:00+00:00         163                   0
# 400 2021-10-27 23:00:00+00:00          66                   0
# 401 2021-10-27 23:00:00+00:00         188                   0
#
#      tutor_empresa_id     category_name                           program_name
# 0                 190  SOPORTE&OPERARIO        Tratamiento Térmico ABP Bergara
# 1                  50              DUAL                             pruebas_01
# 2                 110  SOPORTE&OPERARIO             Operario Control Final CBI
# 3                  41              DUAL               ITI GRADO DUAL 2019-2020
# 4                  41              DUAL               ITI GRADO DUAL 2020-2021
# ..                ...               ...                                    ...
# 397               285      ESPECIALISTA  Maquinista Mecanizados Autogestión MT
# 398               285      ESPECIALISTA  Maquinista Mecanizados Autogestión MT
# 399               287      ESPECIALISTA  Maquinista Mecanizados Autogestión MT
# 400               190  SOPORTE&OPERARIO        Tratamiento Térmico ABP Bergara
# 401               190  SOPORTE&OPERARIO                 Control Visual Mec ABP
#
# [402 rows x 21 columns]

# %%
b=b.drop(['Unnamed: 11'],axis=1)

# %%
b
# Out:
#      user_id useranonimo_name language  last_access  mdl_user_id  role_admin  \
# 0          3      username_03       es          NaN         13.0           0
# 1          3      username_03       es          NaN         13.0           0
# 2          3      username_03       es          NaN         13.0           0
# 3          4      username_04       es          NaN         14.0           0
# 4          4      username_04       es          NaN         14.0           0
# ..       ...              ...      ...          ...          ...         ...
# 397      415     username_415       es          NaN        446.0           0
# 398      415     username_415       es          NaN        446.0           0
# 399      423     username_423       es          NaN        448.0           0
# 400      436     username_436       es          NaN        461.0           0
# 401      436     username_436       es          NaN        461.0           0
#
#      role_manager  role_student  role_tutor      planta_name  perfil_id  \
# 0               0             1           0      ABP Bergara          0
# 1               0             1           0      ABP Bergara          0
# 2               0             1           0      ABP Bergara          0
# 3               0             1           0     Fagorederlan          0
# 4               0             1           0     Fagorederlan          0
# ..            ...           ...         ...              ...        ...
# 397             0             1           0  MT Aretxabaleta          0
# 398             0             1           0  MT Aretxabaleta          0
# 399             0             1           0  MT Aretxabaleta          0
# 400             1             1           1      ABP Bergara          6
# 401             1             1           1      ABP Bergara          6
#
#          perfil_name  active_flag  category_id               date_enroll  \
# 0    Tutores basicos            0            8 2020-05-03 23:00:00+00:00
# 1    Tutores basicos            1            2 2021-07-21 23:00:00+00:00
# 2    Tutores basicos            1            8 2021-09-07 23:00:00+00:00
# 3    Tutores basicos            0            2 2020-06-17 23:00:00+00:00
# 4    Tutores basicos            0            2 2020-09-23 23:00:00+00:00
# ..               ...          ...          ...                       ...
# 397  Tutores basicos            0            5 2021-10-12 23:00:00+00:00
# 398  Tutores basicos            1            5 2021-10-12 23:00:00+00:00
# 399  Tutores basicos            1            5 2021-10-12 23:00:00+00:00
# 400    Tutor empresa            1            8 2021-10-27 23:00:00+00:00
# 401    Tutor empresa            1            8 2021-10-27 23:00:00+00:00
#
#      program_id  tutor_academico_id  tutor_empresa_id     category_name  \
# 0            66                   0               190  SOPORTE&OPERARIO
# 1           145                   0                50              DUAL
# 2           146                   0               110  SOPORTE&OPERARIO
# 3            64                 148                41              DUAL
# 4           135                 148                41              DUAL
# ..          ...                 ...               ...               ...
# 397         163                   0               285      ESPECIALISTA
# 398         163                   0               285      ESPECIALISTA
# 399         163                   0               287      ESPECIALISTA
# 400          66                   0               190  SOPORTE&OPERARIO
# 401         188                   0               190  SOPORTE&OPERARIO
#
#                               program_name
# 0          Tratamiento Térmico ABP Bergara
# 1                               pruebas_01
# 2               Operario Control Final CBI
# 3                 ITI GRADO DUAL 2019-2020
# 4                 ITI GRADO DUAL 2020-2021
# ..                                     ...
# 397  Maquinista Mecanizados Autogestión MT
# 398  Maquinista Mecanizados Autogestión MT
# 399  Maquinista Mecanizados Autogestión MT
# 400        Tratamiento Térmico ABP Bergara
# 401                 Control Visual Mec ABP
#
# [402 rows x 20 columns]

# %%
c=pd.merge(b.drop(['mdl_user_id'],axis=1),Accesos ,on='user_id',copy=False)

# %%
c
# Out:
#        user_id useranonimo_name language  last_access  role_admin  \
# 0            3      username_03       es          NaN           0
# 1            3      username_03       es          NaN           0
# 2            3      username_03       es          NaN           0
# 3            3      username_03       es          NaN           0
# 4            3      username_03       es          NaN           0
# ...        ...              ...      ...          ...         ...
# 51735      436     username_436       es          NaN           0
# 51736      436     username_436       es          NaN           0
# 51737      436     username_436       es          NaN           0
# 51738      436     username_436       es          NaN           0
# 51739      436     username_436       es          NaN           0
#
#        role_manager  role_student  role_tutor  planta_name  perfil_id  \
# 0                 0             1           0  ABP Bergara          0
# 1                 0             1           0  ABP Bergara          0
# 2                 0             1           0  ABP Bergara          0
# 3                 0             1           0  ABP Bergara          0
# 4                 0             1           0  ABP Bergara          0
# ...             ...           ...         ...          ...        ...
# 51735             1             1           1  ABP Bergara          6
# 51736             1             1           1  ABP Bergara          6
# 51737             1             1           1  ABP Bergara          6
# 51738             1             1           1  ABP Bergara          6
# 51739             1             1           1  ABP Bergara          6
#
#            perfil_name  active_flag  category_id               date_enroll  \
# 0      Tutores basicos            0            8 2020-05-03 23:00:00+00:00
# 1      Tutores basicos            0            8 2020-05-03 23:00:00+00:00
# 2      Tutores basicos            0            8 2020-05-03 23:00:00+00:00
# 3      Tutores basicos            1            2 2021-07-21 23:00:00+00:00
# 4      Tutores basicos            1            2 2021-07-21 23:00:00+00:00
# ...                ...          ...          ...                       ...
# 51735    Tutor empresa            1            8 2021-10-27 23:00:00+00:00
# 51736    Tutor empresa            1            8 2021-10-27 23:00:00+00:00
# 51737    Tutor empresa            1            8 2021-10-27 23:00:00+00:00
# 51738    Tutor empresa            1            8 2021-10-27 23:00:00+00:00
# 51739    Tutor empresa            1            8 2021-10-27 23:00:00+00:00
#
#        program_id  tutor_academico_id  tutor_empresa_id     category_name  \
# 0              66                   0               190  SOPORTE&OPERARIO
# 1              66                   0               190  SOPORTE&OPERARIO
# 2              66                   0               190  SOPORTE&OPERARIO
# 3             145                   0                50              DUAL
# 4             145                   0                50              DUAL
# ...           ...                 ...               ...               ...
# 51735         188                   0               190  SOPORTE&OPERARIO
# 51736         188                   0               190  SOPORTE&OPERARIO
# 51737         188                   0               190  SOPORTE&OPERARIO
# 51738         188                   0               190  SOPORTE&OPERARIO
# 51739         188                   0               190  SOPORTE&OPERARIO
#
#                           program_name        description  \
# 0      Tratamiento Térmico ABP Bergara       Login SRM OK
# 1      Tratamiento Térmico ABP Bergara       Login SRM OK
# 2      Tratamiento Térmico ABP Bergara       Login SRM OK
# 3                           pruebas_01       Login SRM OK
# 4                           pruebas_01       Login SRM OK
# ...                                ...                ...
# 51735           Control Visual Mec ABP  Login SRM ERROR 1
# 51736           Control Visual Mec ABP  Login SRM ERROR 1
# 51737           Control Visual Mec ABP  Login SRM ERROR 1
# 51738           Control Visual Mec ABP       Login SRM OK
# 51739           Control Visual Mec ABP       Login SRM OK
#
#                       timestamp  mdl_user_id
# 0     2021-07-22 10:03:45+00:00           13
# 1     2021-08-05 11:33:20+00:00           13
# 2     2021-10-28 12:27:59+00:00           13
# 3     2021-07-22 10:03:45+00:00           13
# 4     2021-08-05 11:33:20+00:00           13
# ...                         ...          ...
# 51735 2021-10-28 15:14:01+00:00          461
# 51736 2021-10-28 15:14:03+00:00          461
# 51737 2021-10-28 15:15:37+00:00          461
# 51738 2021-10-28 15:15:54+00:00          461
# 51739 2021-10-28 15:19:21+00:00          461
#
# [51740 rows x 22 columns]

# %%
d=pd.merge(c,Acceso_1ero_ultimo  ,on='mdl_user_id',copy=False)

# %%
d.head(2)
# Out:
#    user_id useranonimo_name language  last_access  role_admin  role_manager  \
# 0        3      username_03       es          NaN           0             0
# 1        3      username_03       es          NaN           0             0
#
#    role_student  role_tutor  planta_name  perfil_id      perfil_name  \
# 0             1           0  ABP Bergara          0  Tutores basicos
# 1             1           0  ABP Bergara          0  Tutores basicos
#
#    active_flag  category_id               date_enroll  program_id  \
# 0            0            8 2020-05-03 23:00:00+00:00          66
# 1            0            8 2020-05-03 23:00:00+00:00          66
#
#    tutor_academico_id  tutor_empresa_id     category_name  \
# 0                   0               190  SOPORTE&OPERARIO
# 1                   0               190  SOPORTE&OPERARIO
#
#                       program_name   description                 timestamp  \
# 0  Tratamiento Térmico ABP Bergara  Login SRM OK 2021-07-22 10:03:45+00:00
# 1  Tratamiento Térmico ABP Bergara  Login SRM OK 2021-08-05 11:33:20+00:00
#
#   mdl_user_id                           1er acceso  \
# 0          13  martes, 2 de octubre de 2018, 09:46
# 1          13  martes, 2 de octubre de 2018, 09:46
#
#                         ultimo acceso
# 0  jueves, 5 de agosto de 2021, 12:34
# 1  jueves, 5 de agosto de 2021, 12:34

# %%
e=pd.merge(d,Actividades ,on='mdl_user_id',copy=False)

# %%
e.head(2)
# Out:
#    user_id useranonimo_name language  last_access  role_admin  role_manager  \
# 0        3      username_03       es          NaN           0             0
# 1        3      username_03       es          NaN           0             0
#
#    role_student  role_tutor  planta_name  perfil_id      perfil_name  \
# 0             1           0  ABP Bergara          0  Tutores basicos
# 1             1           0  ABP Bergara          0  Tutores basicos
#
#    active_flag  category_id               date_enroll  program_id  \
# 0            0            8 2020-05-03 23:00:00+00:00          66
# 1            0            8 2020-05-03 23:00:00+00:00          66
#
#    tutor_academico_id  tutor_empresa_id     category_name  \
# 0                   0               190  SOPORTE&OPERARIO
# 1                   0               190  SOPORTE&OPERARIO
#
#                       program_name   description                 timestamp  \
# 0  Tratamiento Térmico ABP Bergara  Login SRM OK 2021-07-22 10:03:45+00:00
# 1  Tratamiento Térmico ABP Bergara  Login SRM OK 2021-07-22 10:03:45+00:00
#
#   mdl_user_id                           1er acceso  \
# 0          13  martes, 2 de octubre de 2018, 09:46
# 1          13  martes, 2 de octubre de 2018, 09:46
#
#                         ultimo acceso       course_name  course_id  \
# 0  jueves, 5 de agosto de 2021, 12:34  TALDEEN LIDERGOA        268
# 1  jueves, 5 de agosto de 2021, 12:34  TALDEEN LIDERGOA        268
#
#      category            actividad_name  grade                time
# 0  PERSONALES                      TEST   10.0 2021-08-05 12:34:41
# 1  PERSONALES  TALDEEN LIDERGOA - Total   10.0 2021-08-05 12:34:41

# %%
f=pd.merge(e.drop(['grade','course_name'],axis=1 ),Notas_Cursos ,on=('user_id','course_id'),copy=False,suffixes=('_Itinerarios', '_Notas_Cursos'))

# %%
f.head(2)
# Out:
#    user_id useranonimo_name language  last_access  role_admin  role_manager  \
# 0        3      username_03       es          NaN           0             0
# 1        3      username_03       es          NaN           0             0
#
#    role_student  role_tutor  planta_name  perfil_id      perfil_name  \
# 0             1           0  ABP Bergara          0  Tutores basicos
# 1             1           0  ABP Bergara          0  Tutores basicos
#
#    active_flag_Itinerarios  category_id               date_enroll  program_id  \
# 0                        0            8 2020-05-03 23:00:00+00:00          66
# 1                        0            8 2020-05-03 23:00:00+00:00          66
#
#    tutor_academico_id  tutor_empresa_id     category_name  \
# 0                   0               190  SOPORTE&OPERARIO
# 1                   0               190  SOPORTE&OPERARIO
#
#                       program_name   description                 timestamp  \
# 0  Tratamiento Térmico ABP Bergara  Login SRM OK 2021-07-22 10:03:45+00:00
# 1  Tratamiento Térmico ABP Bergara  Login SRM OK 2021-07-22 10:03:45+00:00
#
#   mdl_user_id                           1er acceso  \
# 0          13  martes, 2 de octubre de 2018, 09:46
# 1          13  martes, 2 de octubre de 2018, 09:46
#
#                         ultimo acceso  course_id    category  \
# 0  jueves, 5 de agosto de 2021, 12:34        268  PERSONALES
# 1  jueves, 5 de agosto de 2021, 12:34        268  PERSONALES
#
#              actividad_name                time  enroll_grade_id  \
# 0                      TEST 2021-08-05 12:34:41            21573
# 1  TALDEEN LIDERGOA - Total 2021-08-05 12:34:41            21573
#
#    active_flag_Notas_Cursos  enroll_id  grade  online_progress  \
# 0                         1        887   10.0              0.0
# 1                         1        887   10.0              0.0
#
#         course_name
# 0  TALDEEN LIDERGOA
# 1  TALDEEN LIDERGOA

# %%
g=pd.merge(f.drop(['course_name'],axis=1 ),Cursos ,on='course_id',copy=False)

# %%
g.head(2)
# Out:
#    user_id useranonimo_name language  last_access  role_admin  role_manager  \
# 0        3      username_03       es          NaN           0             0
# 1        3      username_03       es          NaN           0             0
#
#    role_student  role_tutor  planta_name  perfil_id      perfil_name  \
# 0             1           0  ABP Bergara          0  Tutores basicos
# 1             1           0  ABP Bergara          0  Tutores basicos
#
#    active_flag_Itinerarios  category_id               date_enroll  program_id  \
# 0                        0            8 2020-05-03 23:00:00+00:00          66
# 1                        0            8 2020-05-03 23:00:00+00:00          66
#
#    tutor_academico_id  tutor_empresa_id     category_name  \
# 0                   0               190  SOPORTE&OPERARIO
# 1                   0               190  SOPORTE&OPERARIO
#
#                       program_name   description                 timestamp  \
# 0  Tratamiento Térmico ABP Bergara  Login SRM OK 2021-07-22 10:03:45+00:00
# 1  Tratamiento Térmico ABP Bergara  Login SRM OK 2021-07-22 10:03:45+00:00
#
#   mdl_user_id                           1er acceso  \
# 0          13  martes, 2 de octubre de 2018, 09:46
# 1          13  martes, 2 de octubre de 2018, 09:46
#
#                         ultimo acceso  course_id    category  \
# 0  jueves, 5 de agosto de 2021, 12:34        268  PERSONALES
# 1  jueves, 5 de agosto de 2021, 12:34        268  PERSONALES
#
#              actividad_name                time  enroll_grade_id  \
# 0                      TEST 2021-08-05 12:34:41            21573
# 1  TALDEEN LIDERGOA - Total 2021-08-05 12:34:41            21573
#
#    active_flag_Notas_Cursos  enroll_id  grade  online_progress  \
# 0                         1        887   10.0              0.0
# 1                         1        887   10.0              0.0
#
#         course_name  category_curso_id  hours  sortorder          summary
# 0  TALDEEN LIDERGOA                  5      0      70001  No especificado
# 1  TALDEEN LIDERGOA                  5      0      70001  No especificado

# %%
h=pd.merge(g.drop(['program_name'],axis=1 ),Programas ,on='program_id',copy=False)

# %%
h.head(2)
# Out:
#    user_id useranonimo_name language  last_access  role_admin  role_manager  \
# 0        3      username_03       es          NaN           0             0
# 1        3      username_03       es          NaN           0             0
#
#    role_student  role_tutor  planta_name  perfil_id      perfil_name  \
# 0             1           0  ABP Bergara          0  Tutores basicos
# 1             1           0  ABP Bergara          0  Tutores basicos
#
#    active_flag_Itinerarios  category_id               date_enroll  program_id  \
# 0                        0            8 2020-05-03 23:00:00+00:00          66
# 1                        0            8 2020-05-03 23:00:00+00:00          66
#
#    tutor_academico_id  tutor_empresa_id     category_name   description  \
# 0                   0               190  SOPORTE&OPERARIO  Login SRM OK
# 1                   0               190  SOPORTE&OPERARIO  Login SRM OK
#
#                   timestamp mdl_user_id                           1er acceso  \
# 0 2021-07-22 10:03:45+00:00          13  martes, 2 de octubre de 2018, 09:46
# 1 2021-07-22 10:03:45+00:00          13  martes, 2 de octubre de 2018, 09:46
#
#                         ultimo acceso  course_id    category  \
# 0  jueves, 5 de agosto de 2021, 12:34        268  PERSONALES
# 1  jueves, 5 de agosto de 2021, 12:34        268  PERSONALES
#
#              actividad_name                time  enroll_grade_id  \
# 0                      TEST 2021-08-05 12:34:41            21573
# 1  TALDEEN LIDERGOA - Total 2021-08-05 12:34:41            21573
#
#    active_flag_Notas_Cursos  enroll_id  grade  online_progress  \
# 0                         1        887   10.0              0.0
# 1                         1        887   10.0              0.0
#
#         course_name  category_curso_id  hours  sortorder          summary  \
# 0  TALDEEN LIDERGOA                  5      0      70001  No especificado
# 1  TALDEEN LIDERGOA                  5      0      70001  No especificado
#
#                       program_name program_category_id
# 0  Tratamiento Térmico ABP Bergara    SOPORTE&OPERARIO
# 1  Tratamiento Térmico ABP Bergara    SOPORTE&OPERARIO

# %%
h.duplicated().sum()
# Out:
# 447796

# %%
h=h.drop_duplicates()

# %%
h.duplicated().sum()
# Out:
# 0

# %%
i=pd.merge(h.drop(['program_name'],axis=1 ),Cursos_en_Programas ,on='program_id',copy=False)

# %%
i = i.rename(columns={'course_moodle_id.1':'course_moodle_noun'})

# %%
i.head(2)
# Out:
#    user_id useranonimo_name language  last_access  role_admin  role_manager  \
# 0        3      username_03       es          NaN           0             0
# 1        3      username_03       es          NaN           0             0
#
#    role_student  role_tutor  planta_name  perfil_id      perfil_name  \
# 0             1           0  ABP Bergara          0  Tutores basicos
# 1             1           0  ABP Bergara          0  Tutores basicos
#
#    active_flag_Itinerarios  category_id               date_enroll  program_id  \
# 0                        0            8 2020-05-03 23:00:00+00:00          66
# 1                        0            8 2020-05-03 23:00:00+00:00          66
#
#    tutor_academico_id  tutor_empresa_id     category_name   description  \
# 0                   0               190  SOPORTE&OPERARIO  Login SRM OK
# 1                   0               190  SOPORTE&OPERARIO  Login SRM OK
#
#                   timestamp mdl_user_id                           1er acceso  \
# 0 2021-07-22 10:03:45+00:00          13  martes, 2 de octubre de 2018, 09:46
# 1 2021-07-22 10:03:45+00:00          13  martes, 2 de octubre de 2018, 09:46
#
#                         ultimo acceso  course_id    category actividad_name  \
# 0  jueves, 5 de agosto de 2021, 12:34        268  PERSONALES           TEST
# 1  jueves, 5 de agosto de 2021, 12:34        268  PERSONALES           TEST
#
#                  time  enroll_grade_id  active_flag_Notas_Cursos  enroll_id  \
# 0 2021-08-05 12:34:41            21573                         1        887
# 1 2021-08-05 12:34:41            21573                         1        887
#
#    grade  online_progress       course_name  category_curso_id  hours  \
# 0   10.0              0.0  TALDEEN LIDERGOA                  5      0
# 1   10.0              0.0  TALDEEN LIDERGOA                  5      0
#
#    sortorder          summary program_category_id  program_course_online_id  \
# 0      70001  No especificado    SOPORTE&OPERARIO                      5220
# 1      70001  No especificado    SOPORTE&OPERARIO                      5640
#
#    course_moodle_id  conocimiento_id  num_periodo  \
# 0               144               90            1
# 1                72               24            1
#
#              course_moodle_noun              conocimiento_name  \
# 0  TRATAMIENTO TÉRMICO ABP B_N2    ACABADO_Tratamiento Térmico
# 1  INTRODUCCIÓN EN PRL Y MA ABP  ACOGIDA PRL Y MEDIO AMBIENTE
#
#                       program_name
# 0  Tratamiento Térmico ABP Bergara
# 1  Tratamiento Térmico ABP Bergara

# %%
i.duplicated().sum()
# Out:
# 0

# %%
Todo=pd.merge(i.drop(['conocimiento_name'],axis=1 ),Conocimientos ,on='conocimiento_id',copy=False)

# %%
Todo.sample(10)
# Out:
#           user_id useranonimo_name language  last_access  role_admin  \
# 3076206       138     username_138       es          NaN           0
# 1408371       138     username_138       es          NaN           0
# 19006204      138     username_138       es          NaN           0
# 298806        138     username_138       es          NaN           0
# 13126023      138     username_138       es          NaN           0
# 18320953      138     username_138       es          NaN           0
# 15910529      138     username_138       es          NaN           0
# 15490551      138     username_138       es          NaN           0
# 3684992       138     username_138       es          NaN           0
# 309215        138     username_138       es          NaN           0
#
#           role_manager  role_student  role_tutor   planta_name  perfil_id  \
# 3076206              0             1           0  ABP Arrasate          0
# 1408371              0             1           0  ABP Arrasate          6
# 19006204             0             1           0  ABP Arrasate          6
# 298806               0             1           0  ABP Arrasate          0
# 13126023             0             1           0  ABP Arrasate          6
# 18320953             0             1           0  ABP Arrasate          6
# 15910529             0             1           0  ABP Arrasate          6
# 15490551             0             1           0  ABP Arrasate          6
# 3684992              0             1           0  ABP Arrasate          0
# 309215               0             1           0  ABP Arrasate          0
#
#               perfil_name  active_flag_Itinerarios  category_id  \
# 3076206   Tutores basicos                        0            1
# 1408371     Tutor empresa                        0            8
# 19006204    Tutor empresa                        0            8
# 298806    Tutores basicos                        0            8
# 13126023    Tutor empresa                        0            5
# 18320953    Tutor empresa                        1            8
# 15910529    Tutor empresa                        0            5
# 15490551    Tutor empresa                        0            5
# 3684992   Tutores basicos                        0            1
# 309215    Tutores basicos                        0            8
#
#                        date_enroll  program_id  tutor_academico_id  \
# 3076206  2020-05-09 23:00:00+00:00          61                   0
# 1408371  2020-11-03 00:00:00+00:00          66                   0
# 19006204 2021-05-04 23:00:00+00:00         180                   0
# 298806   2020-11-03 00:00:00+00:00          66                   0
# 13126023 2020-12-14 00:00:00+00:00         163                 148
# 18320953 2021-07-12 23:00:00+00:00         180                   0
# 15910529 2021-05-31 23:00:00+00:00         163                   0
# 15490551 2020-12-14 00:00:00+00:00         163                 148
# 3684992  2020-06-07 23:00:00+00:00          61                   0
# 309215   2021-07-06 23:00:00+00:00          66                   0
#
#           tutor_empresa_id     category_name        description  \
# 3076206                  0           TÉCNICO       Login SRM OK
# 1408371                 50  SOPORTE&OPERARIO       Login SRM OK
# 19006204               110  SOPORTE&OPERARIO  Login SRM ERROR 1
# 298806                  50  SOPORTE&OPERARIO       Login SRM OK
# 13126023                77      ESPECIALISTA       Login SRM OK
# 18320953               110  SOPORTE&OPERARIO       Login SRM OK
# 15910529               110      ESPECIALISTA       Login SRM OK
# 15490551                77      ESPECIALISTA       Login SRM OK
# 3684992                 50           TÉCNICO       Login SRM OK
# 309215                 110  SOPORTE&OPERARIO  Login SRM ERROR 1
#
#                          timestamp mdl_user_id  \
# 3076206  2021-01-26 16:11:55+00:00         183
# 1408371  2021-01-14 10:55:04+00:00         183
# 19006204 2021-05-05 11:08:01+00:00         183
# 298806   2020-05-19 17:58:37+00:00         183
# 13126023 2021-06-10 14:44:39+00:00         183
# 18320953 2021-07-07 11:40:06+00:00         183
# 15910529 2020-06-11 09:00:16+00:00         183
# 15490551 2020-11-04 16:08:29+00:00         183
# 3684992  2020-11-12 13:03:43+00:00         183
# 309215   2020-12-14 15:27:41+00:00         183
#
#                                1er acceso                       ultimo acceso  \
# 3076206   lunes, 4 de mayo de 2020, 17:04  martes, 13 de julio de 2021, 15:10
# 1408371   lunes, 4 de mayo de 2020, 17:04  martes, 13 de julio de 2021, 15:10
# 19006204  lunes, 4 de mayo de 2020, 17:04  martes, 13 de julio de 2021, 15:10
# 298806    lunes, 4 de mayo de 2020, 17:04  martes, 13 de julio de 2021, 15:10
# 13126023  lunes, 4 de mayo de 2020, 17:04  martes, 13 de julio de 2021, 15:10
# 18320953  lunes, 4 de mayo de 2020, 17:04  martes, 13 de julio de 2021, 15:10
# 15910529  lunes, 4 de mayo de 2020, 17:04  martes, 13 de julio de 2021, 15:10
# 15490551  lunes, 4 de mayo de 2020, 17:04  martes, 13 de julio de 2021, 15:10
# 3684992   lunes, 4 de mayo de 2020, 17:04  martes, 13 de julio de 2021, 15:10
# 309215    lunes, 4 de mayo de 2020, 17:04  martes, 13 de julio de 2021, 15:10
#
#           course_id                   category  \
# 3076206          86                  GENERALES
# 1408371         207                  GENERALES
# 19006204        144  TÉCNICOS/TECNOLÓGICOS ABP
# 298806          280                   TÉCNICOS
# 13126023        280                   TÉCNICOS
# 18320953         66                  GENERALES
# 15910529        212   TÉCNICO / TECNOLÓGICO MT
# 15490551        247                   TÉCNICOS
# 3684992         144  TÉCNICOS/TECNOLÓGICOS ABP
# 309215          280                   TÉCNICOS
#
#                                      actividad_name                time  \
# 3076206   COMPETENCIAS PERSONALES - GENERAL - Total 2020-06-11 13:16:33
# 1408371                          Cuestionario igual 1999-01-01 00:00:00
# 19006204       TRATAMIENTO TÉRMICO ABP B_N2 - Total 2020-09-29 16:28:33
# 298806               HOMOLOGACION OPERARIO ACABADOS 2021-06-14 11:34:43
# 13126023             HOMOLOGACION OPERARIO ACABADOS 2021-06-14 11:34:43
# 18320953                     Finalización del CURSO 1999-01-01 00:00:00
# 15910529                       MANDOAREN EBALUAZIOA 1999-01-01 00:00:00
# 15490551                      DESMAZAROTADO - Total 1999-01-01 00:00:00
# 3684992        TRATAMIENTO TÉRMICO ABP B_N2 - Total 2020-09-29 16:28:33
# 309215                           Homologación MANDO 2021-06-28 09:37:47
#
#           enroll_grade_id  active_flag_Notas_Cursos  enroll_id   grade  \
# 3076206              9549                         1        552 -999.00
# 1408371             18708                         1        814    4.53
# 19006204            13978                         1        717    0.00
# 298806              19838                         1        846   20.00
# 13126023            19513                         1        837   10.00
# 18320953            14517                         1        724 -999.00
# 15910529            18455                         1        762    0.00
# 15490551            19514                         1        837 -999.00
# 3684992             13978                         1        717    0.00
# 309215              19513                         1        837   10.00
#
#           online_progress                        course_name  \
# 3076206              50.0  COMPETENCIAS PERSONALES - GENERAL
# 1408371               0.0  FED_01_ES_02 - Información Moodle
# 19006204              0.0       TRATAMIENTO TÉRMICO ABP B_N2
# 298806              100.0   CONTROL VISUAL OPERARIO ACABADOS
# 13126023              0.0   CONTROL VISUAL OPERARIO ACABADOS
# 18320953           -999.0  FED_01_ES_01 - Información Moodle
# 15910529              0.0                   CALIDAD GENÉRICA
# 15490551           -999.0                      DESMAZAROTADO
# 3684992               0.0       TRATAMIENTO TÉRMICO ABP B_N2
# 309215                0.0   CONTROL VISUAL OPERARIO ACABADOS
#
#           category_curso_id  hours  sortorder  \
# 3076206                  35      7      50008
# 1408371                  35     20      50006
# 19006204                 27      6     110017
# 298806                    7      0     100008
# 13126023                  7      0     100008
# 18320953                 35     10      50004
# 15910529                 42      0     130002
# 15490551                  7      0     100009
# 3684992                  27      6     110017
# 309215                    7      0     100008
#
#                                                     summary  \
# 3076206                                     No especificado
# 1408371                                     No especificado
# 19006204                                    No especificado
# 298806                                      No especificado
# 13126023                                    No especificado
# 18320953  Este módulo contiene información para los Admi...
# 15910529                                    No especificado
# 15490551  <p>Curso específico para conocer el proceso de...
# 3684992                                     No especificado
# 309215                                      No especificado
#
#          program_category_id  program_course_online_id  course_moodle_id  \
# 3076206              TÉCNICO                      5653                72
# 1408371     SOPORTE&OPERARIO                      5641                74
# 19006204    SOPORTE&OPERARIO                      5631               250
# 298806      SOPORTE&OPERARIO                      5220               144
# 13126023        ESPECIALISTA                      5574               220
# 18320953    SOPORTE&OPERARIO                      5635               246
# 15910529        ESPECIALISTA                      5685               254
# 15490551        ESPECIALISTA                      5683               236
# 3684992              TÉCNICO                      5653                72
# 309215      SOPORTE&OPERARIO                      5652               193
#
#           conocimiento_id  num_periodo                  course_moodle_noun  \
# 3076206                24            0        INTRODUCCIÓN EN PRL Y MA ABP
# 1408371                24            1  EVALUACIÓN RIESGOS DEL PUESTO - TT
# 19006204              145            1                      CONTROL VISUAL
# 298806                 90            1        TRATAMIENTO TÉRMICO ABP B_N2
# 13126023              107            1               PROCESO + HERRAMENTAL
# 18320953              145            1           INTRODUCCIÓN ÁREA ACABADO
# 15910529              136            0                              CC 382
# 15490551              125            0                       CE 096 (BMT6)
# 3684992                24            0        INTRODUCCIÓN EN PRL Y MA ABP
# 309215                 90            2        TRATAMIENTO TÉRMICO ABP B_N3
#
#                                    program_name  \
# 3076206                         Programa PILOTO
# 1408371         Tratamiento Térmico ABP Bergara
# 19006204             Operario Control Final LPC
# 298806          Tratamiento Térmico ABP Bergara
# 13126023  Maquinista Mecanizados Autogestión MT
# 18320953             Operario Control Final LPC
# 15910529  Maquinista Mecanizados Autogestión MT
# 15490551  Maquinista Mecanizados Autogestión MT
# 3684992                         Programa PILOTO
# 309215          Tratamiento Térmico ABP Bergara
#
#                       conocimiento_name  created_by  \
# 3076206   ACOGIDA PRL Y MEDIO AMBIENTE          135
# 1408371   ACOGIDA PRL Y MEDIO AMBIENTE          135
# 19006204              CONTROL FINAL LPC         145
# 298806      ACABADO_Tratamiento Térmico         145
# 13126023                     MECANIZADO         145
# 18320953              CONTROL FINAL LPC         145
# 15910529            MECANIZADO - CC 382         145
# 15490551     MECANIZADO - CE 096 (BMT6)         145
# 3684992   ACOGIDA PRL Y MEDIO AMBIENTE          135
# 309215      ACABADO_Tratamiento Térmico         145
#
#           categoria_conocimiento_id              categoria_conocimiento_name
# 3076206                          11                                  ACOGIDA
# 1408371                          11                                  ACOGIDA
# 19006204                          7                                 TÉCNICOS
# 298806                           79                TÉCNICOS/TECNOLÓGICOS ABP
# 13126023                        102                 TÉCNICO / TECNOLÓGICO MT
# 18320953                          7                                 TÉCNICOS
# 15910529                        153  TÉCNICO / TECNOLÓGICO MT - REFERENCIAS
# 15490551                        153  TÉCNICO / TECNOLÓGICO MT - REFERENCIAS
# 3684992                          11                                  ACOGIDA
# 309215                           79                TÉCNICOS/TECNOLÓGICOS ABP

# %%
Todo.duplicated().sum()
# Out:
# 0

# %%
Todo.shape
# Out:
# (20143944, 48)
